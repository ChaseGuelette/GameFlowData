# %%
from nba_api.stats.static import teams

# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print("Number of teams fetched: {}".format(len(nba_teams)))
nba_teams[:3]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits
import pandas as pd

stats = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(team_id = '1610612737')
df = stats.get_data_frames()[0]
pd.set_option('display.max.columns', 55)
df
# Out:
#   GROUP_SET GROUP_VALUE SEASON_YEAR  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0   Overall     2024-25     2024-25  42  22  20  0.524  2031.0  1794  3874
#
#    FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB   AST  \
# 0   0.463   548  1551    0.353  780  999   0.781   519  1397  1916  1237
#
#      TOV  STL  BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  \
# 0  676.0  431  227   227  776  832  4916       -83.0        1       1       1
#
#    W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# ...

# %%
from nba_api.stats.library import parameters
print(parameters.Stat.__dict__)
# Out:
# {'__module__': 'nba_api.stats.library.parameters', 'points': 'PTS', 'rebounds': 'REB', 'assists': 'AST', 'field_goal_percent': 'FG_PCT', 'free_throw_percent': 'FT_PCT', 'threes_percent': 'FG3_PCT', 'steals': 'STL', 'blocks': 'BLK', 'default': 'PTS', '__dict__': <attribute '__dict__' of 'Stat' objects>, '__weakref__': <attribute '__weakref__' of 'Stat' objects>, '__doc__': None}

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits
import pandas as pd

stats = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(
    team_id = '1610612738',
    measure_type_detailed_defense = 'Base')
df = stats.get_data_frames()[0]
pd.set_option('display.max.columns', 55)
df
# Out:
#   GROUP_SET GROUP_VALUE SEASON_YEAR  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0   Overall     2024-25     2024-25  43  30  13  0.698  2084.0  1793  3910
#
#    FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB   AST  \
# 0   0.459   766  2109    0.363  708  892   0.794   481  1469  1950  1095
#
#      TOV  STL  BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  \
# 0  510.0  328  248   183  693  801  5060       413.0        1       1       1
#
#    W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# ...

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits
import pandas as pd

stats = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(
    team_id = '1610612737',
    measure_type_detailed_defense = 'Scoring')
df = stats.get_data_frames()[0]
pd.set_option('display.max.columns', 55)
df
# Out:
#   GROUP_SET GROUP_VALUE SEASON_YEAR  GP   W   L  W_PCT   MIN  PCT_FGA_2PT  \
# 0   Overall     2024-25     2024-25  43  22  21  0.512  48.3          0.6
#
#    PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  PCT_PTS_FB  \
# 0          0.4         0.51           0.041        0.331       0.145
#
#    PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  PCT_UAST_2PM  \
# 0       0.159            0.163          0.469        0.634         0.366
#
#    PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM  GP_RANK  W_RANK  \
# 0        0.814         0.186        0.688         0.312        1       1
#
#    L_RANK  W_PCT_RANK  MIN_RANK  PCT_FGA_2PT_RANK  PCT_FGA_3PT_RANK  \
# 0       1           1         1                 1                 1
#
#    PCT_PTS_2PT_RANK  PCT_PTS_2PT_MR_RANK  PCT_PTS_3PT_RANK  PCT_PTS_FB_RANK  \
# 0                 1                    1                 1                1
#
#    PCT_PTS_FT_RANK  PCT_PTS_OFF_TOV_RANK  PCT_PTS_PAINT_RANK  \
# ...

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits
import pandas as pd

stats = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(
    team_id = '1610612737',
    measure_type_detailed_defense = 'Scoring',
    per_mode_detailed='Per100Possessions')
df = stats.get_data_frames()[0]
pd.set_option('display.max.columns', 55)
df
# Out:
#   GROUP_SET GROUP_VALUE SEASON_YEAR  GP   W   L  W_PCT   MIN  PCT_FGA_2PT  \
# 0   Overall     2024-25     2024-25  43  22  21  0.512  48.3          0.6
#
#    PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  PCT_PTS_FB  \
# 0          0.4         0.51           0.041        0.331       0.145
#
#    PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  PCT_UAST_2PM  \
# 0       0.159            0.163          0.469        0.634         0.366
#
#    PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM  GP_RANK  W_RANK  \
# 0        0.814         0.186        0.688         0.312        1       1
#
#    L_RANK  W_PCT_RANK  MIN_RANK  PCT_FGA_2PT_RANK  PCT_FGA_3PT_RANK  \
# 0       1           1         1                 1                 1
#
#    PCT_PTS_2PT_RANK  PCT_PTS_2PT_MR_RANK  PCT_PTS_3PT_RANK  PCT_PTS_FB_RANK  \
# 0                 1                    1                 1                1
#
#    PCT_PTS_FT_RANK  PCT_PTS_OFF_TOV_RANK  PCT_PTS_PAINT_RANK  \
# ...

# %%
#heres how we get player data:
from nba_api.stats.static import players

# Get all players
all_players = players.get_players()

# Find specific player
player = players.find_players_by_full_name('Trae Young')[0]
player_id = player['id']  # Returns 1629027

# Or search by last name (returns list of matches)
young_players = players.find_players_by_last_name('Young')
print(player_id)
# Out:
# 1629027

# %%
from nba_api.stats.endpoints import leaguedashplayerstats 
from nba_api.stats.endpoints import playercareerstats 
from nba_api.stats.endpoints import playergamelog 

# stats = playercareerstats.PlayerCareerStats(player_id='1629027')
# df = stats.get_data_frames()[0]
# # df
# stats = leaguedashplayerstats.LeagueDashPlayerStats()
# df = stats.get_data_frames()[0]
# df
# df
stats = playergamelog.PlayerGameLog(player_id='1629027')
df = stats.get_data_frames()[0]
df
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22024    1629027  0022400612  JAN 22, 2025  ATL vs. DET  L   40    5
# 1      22024    1629027  0022400602  JAN 20, 2025    ATL @ NYK  L   35    8
# 2      22024    1629027  0022400587  JAN 18, 2025    ATL @ BOS  W   39   10
# 3      22024    1629027  0022400556  JAN 14, 2025  ATL vs. PHX  W   38   13
# 4      22024    1629027  0022400522  JAN 09, 2025    ATL @ PHX  L   34    6
# 5      22024    1629027  0022400506  JAN 07, 2025    ATL @ UTA  W   37    6
# 6      22024    1629027  0022400486  JAN 04, 2025    ATL @ LAC  L   34    7
# 7      22024    1629027  0022400477  JAN 03, 2025    ATL @ LAL  L   36   10
# 8      22024    1629027  0022400461  JAN 01, 2025    ATL @ DEN  L   30    8
# 9      22024    1629027  0022400438  DEC 29, 2024    ATL @ TOR  W   32   10
# 10     22024    1629027  0022400427  DEC 28, 2024  ATL vs. MIA  W   37    3
# ...

# %%
# GP = Games Played
# GS = Games Started
# MIN = Minutes
# FGM = Field Goals Made
# FGA = Field Goals Attempted
# FG_PCT = Field Goal Percentage
# FG3M = 3-Point Field Goals Made
# FG3A = 3-Point Field Goals Attempted
# FG3_PCT = 3-Point Field Goal Percentage
# FTM = Free Throws Made
# FTA = Free Throws Attempted
# FT_PCT = Free Throw Percentage
# OREB = Offensive Rebounds
# DREB = Defensive Rebounds
# REB = Total Rebounds
# AST = Assists
# STL = Steals
# BLK = Blocks
# TOV = Turnovers
# PF = Personal Fouls
# PTS = Points

# SEASON_ID = Season Year (e.g., "22023")
# Player_ID = Unique Player Identifier
# Game_ID = Unique Game Identifier
# GAME_DATE = Date of Game
# MATCHUP = Teams Playing (e.g., "ATL vs. BOS")
# WL = Win or Loss
# MIN = Minutes Played
# FGM = Field Goals Made
# FGA = Field Goals Attempted
# FG_PCT = Field Goal Percentage
# FG3M = 3-Pointers Made
# FG3A = 3-Pointers Attempted
# FG3_PCT = 3-Point Percentage
# FTM = Free Throws Made
# FTA = Free Throws Attempted
# FT_PCT = Free Throw Percentage
# OREB = Offensive Rebounds
# DREB = Defensive Rebounds
# REB = Total Rebounds
# AST = Assists
# STL = Steals
# BLK = Blocks
# TOV = Turnovers
# PF = Personal Fouls
# PTS = Points
# PLUS_MINUS = Plus/Minus Score
# VIDEO_AVAILABLE = Video Highlight Available

# %%
from nba_api.stats.endpoints import teamandplayersvsplayers

stats = teamandplayersvsplayers.TeamAndPlayersVsPlayers()
df = stats.get_data_frames()[0]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 3
#       1 from nba_api.stats.endpoints import teamandplayersvsplayers
# ----> 3 stats = teamandplayersvsplayers.TeamAndPlayersVsPlayers()
#       4 df = stats.get_data_frames()[0]
#       5 df
#
# TypeError: TeamAndPlayersVsPlayers.__init__() missing 12 required positional arguments: 'vs_team_id', 'vs_player_id5', 'vs_player_id4', 'vs_player_id3', 'vs_player_id2', 'vs_player_id1', 'team_id', 'player_id5', 'player_id4', 'player_id3', 'player_id2', and 'player_id1'

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits

stats = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(team_id='1610612737')
df = stats.get_data_frames()[0]
df
# Out:
#   GROUP_SET GROUP_VALUE SEASON_YEAR  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0   Overall     2024-25     2024-25  43  22  21  0.512  2079.0  1833  3977
#
#    FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  FT_PCT  OREB  DREB   REB   AST  \
# 0   0.461   554  1589    0.349  800  1025    0.78   534  1429  1963  1262
#
#      TOV  STL  BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  \
# 0  690.0  445  230   237  790  851  5020       -93.0        1       1       1
#
#    W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# ...

# %%
from nba_api.stats.endpoints import teamdashboardbyshootingsplits

stats = teamdashboardbyshootingsplits.TeamDashboardByShootingSplits(
    team_id='1610612737',
    measure_type_detailed_defense='Base')
df = stats.get_data_frames()[0]
df
# Out:
#   GROUP_SET GROUP_VALUE   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  EFG_PCT  \
# 0   Overall     2024-25  1833  3977   0.461   554  1589    0.349    0.531
#
#    BLKA  PCT_AST_2PM  PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  \
# 0   237        0.634         0.366        0.814         0.186        0.688
#
#    PCT_UAST_FGM  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  FG3A_RANK  \
# 0         0.312         1         1            1          1          1
#
#    FG3_PCT_RANK  EFG_PCT_RANK  BLKA_RANK  PCT_AST_2PM_RANK  PCT_UAST_2PM_RANK  \
# 0             1             1          1                 1                  1
#
#    PCT_AST_3PM_RANK  PCT_UAST_3PM_RANK  PCT_AST_FGM_RANK  PCT_UAST_FGM_RANK
# 0                 1                  1                 1                  1

# %%
from nba_api.stats.endpoints import teamdashlineups

stats = teamdashlineups.TeamDashLineups(team_id='1610612737')
df = stats.get_data_frames()
df
# Out:
# [  GROUP_SET GROUP_VALUE     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME  GP   W  \
#  0   Overall     2024-25  1610612737               ATL  Atlanta Hawks  43  22
#
#      L  W_PCT     MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  \
#  0  21  0.512  2079.0  1833  3977   0.461   554  1589    0.349  800  1025
#
#     FT_PCT  OREB  DREB   REB   AST    TOV  STL  BLK  BLKA  ...  PLUS_MINUS  \
#  0    0.78   534  1429  1963  1262  690.0  445  230   237  ...       -93.0
#
#     GP_RANK  W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  \
#  0        1       1       1           1         1         1         1
#
#     FG_PCT_RANK  FG3M_RANK  FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  \
#  0            1          1          1             1         1         1
#
#     FT_PCT_RANK  OREB_RANK  DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  \
#  0            1          1          1         1         1         1         1
#
# ...

# %%
# from nba_api.stats.endpoints import teamplayerdashboard

# roster = teamplayerdashboard.TeamPlayerDashboard(team_id='1610612737')
# roster_df = stats.get_data_frames()[0]
# roster_df

# %%
from nba_api.stats.endpoints import commonteamroster

roster = commonteamroster.CommonTeamRoster(team_id='1610612737')  # Hawks
roster_df = roster.get_data_frames()[0]
roster_df
# Out:
#         TeamID SEASON LeagueID              PLAYER   NICKNAME  \
# 0   1610612737   2024       00       Jalen Johnson      Jalen
# 1   1610612737   2024       00      Keaton Wallace     Keaton
# 2   1610612737   2024       00         Kobe Bufkin       Kobe
# 3   1610612737   2024       00       Dyson Daniels      Dyson
# 4   1610612737   2024       00         David Roddy      David
# 5   1610612737   2024       00  Zaccharie Risacher  Zaccharie
# 6   1610612737   2024       00          Trae Young       Trae
# 7   1610612737   2024       00     De'Andre Hunter   De'Andre
# 8   1610612737   2024       00   Bogdan Bogdanović     Bogdan
# 9   1610612737   2024       00        Clint Capela      Clint
# 10  1610612737   2024       00      Onyeka Okongwu     Onyeka
# 11  1610612737   2024       00      Mouhamed Gueye   Mouhamed
# 12  1610612737   2024       00     Larry Nance Jr.      Larry
# 13  1610612737   2024       00    Garrison Mathews   Garrison
# ...

# %%
#ok now, I want to create a loop that loops through all the players from a given team ID
for index, row in roster_df.iterrows():
    player_id = row['PLAYER_ID']
    player_name = row['PLAYER']
    age = row['AGE']
    print("getting stats for " + player_name)
# Out:
# getting stats for Jalen Johnson
# getting stats for Keaton Wallace
# getting stats for Kobe Bufkin
# getting stats for Dyson Daniels
# getting stats for David Roddy
# getting stats for Zaccharie Risacher
# getting stats for Trae Young
# getting stats for De'Andre Hunter
# getting stats for Bogdan Bogdanović
# getting stats for Clint Capela
# getting stats for Onyeka Okongwu
# getting stats for Mouhamed Gueye
# getting stats for Larry Nance Jr.
# getting stats for Garrison Mathews
# getting stats for Dominick Barlow
# getting stats for Vít Krejčí
# getting stats for Daeqwon Plowden
# getting stats for Cody Zeller

# %%
#next, as we loop through that, i want to pull their career statistics
from nba_api.stats.endpoints import playercareerstats
#note that the nba_api has rate limiting, so we cant go too fast
from requests.exceptions import ReadTimeout
import random
import time 
import pandas as pd

team_roster = pd.DataFrame()
player_names = []

for index, row in roster_df.iterrows():

    player_id = row['PLAYER_ID']
    player_name = row['PLAYER']
    age = row['AGE'] 
    player_names.append(player_name)
    
    while True:
        try:
            print(f"getting stats for {player_name}")
            stats = playercareerstats.PlayerCareerStats(player_id=player_id)
            player_stats = stats.get_data_frames()[0]
            
            #ok now we need to process the data we are pulling 
            most_recent_season = pd.DataFrame([player_stats.iloc[-1]])
            team_roster = pd.concat([team_roster, most_recent_season])
            
            
            time.sleep(round(random.uniform(0.5, 1.5), 1))
            break
        except ReadTimeout:
            print(f"Timeout for {player_name} - retrying after 5 seconds")
            time.sleep(5)
            continue

team_roster.insert(0, 'PLAYER_NAME', player_names)
print("finished")
# Out:
# getting stats for Jalen Johnson
# getting stats for Keaton Wallace
# getting stats for Kobe Bufkin
# getting stats for Dyson Daniels
# getting stats for David Roddy
# getting stats for Zaccharie Risacher
# getting stats for Trae Young
# getting stats for De'Andre Hunter
# getting stats for Bogdan Bogdanović
# getting stats for Clint Capela
# getting stats for Onyeka Okongwu
# getting stats for Mouhamed Gueye
# getting stats for Larry Nance Jr.
# getting stats for Garrison Mathews
# getting stats for Dominick Barlow
# getting stats for Vít Krejčí
# getting stats for Daeqwon Plowden
# getting stats for Cody Zeller
# finished

# %%
team_roster = team_roster.reset_index(drop=True)
team_roster
# Out:
#            PLAYER_NAME  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 0        Jalen Johnson    1630552   2024-25        00  1610612737
# 1       Keaton Wallace    1630811   2024-25        00  1610612737
# 2          Kobe Bufkin    1641723   2024-25        00  1610612737
# 3        Dyson Daniels    1630700   2024-25        00  1610612737
# 4          David Roddy    1631223   2024-25        00  1610612737
# 5   Zaccharie Risacher    1642258   2024-25        00  1610612737
# 6           Trae Young    1629027   2024-25        00  1610612737
# 7      De'Andre Hunter    1629631   2024-25        00  1610612737
# 8    Bogdan Bogdanović     203992   2024-25        00  1610612737
# 9         Clint Capela     203991   2024-25        00  1610612737
# 10      Onyeka Okongwu    1630168   2024-25        00  1610612737
# 11      Mouhamed Gueye    1631243   2024-25        00  1610612737
# 12     Larry Nance Jr.    1626204   2024-25        00  1610612737
# ...

# %%
# from nba_api.stats.endpoints import playercareerstats

# team_roster = pd.DataFrame()
# #each players career stats will be added to a dataframe

# stats = playercareerstats.PlayerCareerStats(player_id='1629027') #trea young
# player_stats = stats.get_data_frames()[0]
# most_recent_season = pd.DataFrame([player_stats.iloc[-1]])
# team_roster = pd.concat([team_roster, most_recent_season])

# stats = playercareerstats.PlayerCareerStats(player_id='1628369') #Jayson Tatum
# player_stats = stats.get_data_frames()[0]
# most_recent_season = pd.DataFrame([player_stats.iloc[-1]])
# team_roster = pd.concat([team_roster, most_recent_season])

# #in the loop above, we can just keep a running list of the players names, and then insert the column at the end
# team_roster.insert(0, 'PLAYER_NAME', ['Trae Young', 'Jayson Tatum'])

# %%
# #then I want to figure out how to basically relate that big dataframe to the team, and store that information
# team_roster

# %%
# #so down here, once I have that big dataframe, i want to transition to storing it somehow
# import random
# i = 0
# while i < 20:
#     num = round(random.uniform(0.5, 1.5), 1)
#     print(num)
#     i+=1

# %%
team_roster.to_excel('hawks.xlsx')

# %%
#full team stats, aquired and stored in a sql database
from nba_api.stats.endpoints import commonteamroster
from nba_api.stats.endpoints import playercareerstats
#note that the nba_api has rate limiting, so we cant go too fast
from requests.exceptions import ReadTimeout
import random
import time 
import pandas as pd

#we need to import the team roster, turn it into a dataframe
roster = commonteamroster.CommonTeamRoster(team_id='1610612737')  # Hawks
roster_df = roster.get_data_frames()[0]

#create an empty team roster 
team_roster = pd.DataFrame()
player_names = []

#next, as we loop through that, i want to pull their career statistics
for index, row in roster_df.iterrows():
    
    player_id = row['PLAYER_ID']
    player_name = row['PLAYER']
    age = row['AGE'] 
    player_names.append(player_name)
    
    while True:
        try:
            print(f"getting stats for {player_name}")
            stats = playercareerstats.PlayerCareerStats(player_id=player_id)
            player_stats = stats.get_data_frames()[0]
            
            #ok now we need to process the data we are pulling 
            most_recent_season = pd.DataFrame([player_stats.iloc[-1]])
            team_roster = pd.concat([team_roster, most_recent_season])
            
            
            time.sleep(round(random.uniform(0.5, 1.5), 1))
            break
        except ReadTimeout:
            print(f"Timeout for {player_name} - retrying after 5 seconds")
            time.sleep(5)
            continue

team_roster.insert(0, 'PLAYER_NAME', player_names)
print('finished')
#once we've created the dataframe, we want to push that to a SQL database
# Out:
# getting stats for Jalen Johnson
# getting stats for Keaton Wallace
# getting stats for Kobe Bufkin
# getting stats for Dyson Daniels
# getting stats for David Roddy
# getting stats for Zaccharie Risacher
# getting stats for Trae Young
# getting stats for De'Andre Hunter
# getting stats for Bogdan Bogdanović
# getting stats for Clint Capela
# getting stats for Onyeka Okongwu
# getting stats for Mouhamed Gueye
# getting stats for Larry Nance Jr.
# getting stats for Garrison Mathews
# getting stats for Dominick Barlow
# getting stats for Vít Krejčí
# getting stats for Daeqwon Plowden
# getting stats for Cody Zeller
# finished

# %%
import pandas as pd
from sqlalchemy import create_engine

#connection string: dialect+driver://user:password@server/database
engine = create_engine('postgresql://chase:yourpassword@localhost:5433/TeamData')

#df to sql
#append, fail, repalce for the if_exists parameter
team_roster.to_sql('hawks_team_roster', engine, if_exists='replace', index=False)
# Out:
# 18

# %%
# team_roster_df = pd.read_sql_query('SELECT * FROM hawks_team_roster ', engine)
# team_roster_df

# %%
#now I want to work on iterating through a list of all of the NBA teams
from nba_api.stats.static import teams

# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print("Number of teams fetched: {}".format(len(nba_teams)))
nba_teams[:3]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
for team in nba_teams:
    print(team['id'])
    print(team['full_name'])
    print(team)
    print()
# Out:
# 1610612737
# Atlanta Hawks
# {'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Georgia', 'year_founded': 1949}
#
# 1610612738
# Boston Celtics
# {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}
#
# 1610612739
# Cleveland Cavaliers
# {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}
#
# 1610612740
# New Orleans Pelicans
# {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}
#
# 1610612741
# Chicago Bulls
# {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}
#
# 1610612742
# ...
