# %%
#Combine pandas dataframes and opstgre sql database
#create connection
#create curso
#actual sql 
#commit 
#close connection

# %%
#import physcopg2
import psycopg2

# %%
#if we have data on a server, then we need the server ip address
pgconn = psycopg2.connect(
    host='localhost',
    user='chase',
    password='yourpassword', 
    database='TeamData',
    port='5433')

# %%
#cursor
pgcursor = pgconn.cursor()

# %%
#required code
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
#drop db
#this is where we write our SQL code
pgcursor.execute('DROP DATABASE IF EXISTS teamDataPoints')

# %%
#create the new database
pgcursor.execute('CREATE DATABASE teamDataPoints')

# %%
#commit method
#basically if we do anything with SQL and dont save it it wont work
pgconn.commit()

# %%
#once we are done, we should close the connection
pgconn.close()

# %%
#data
# data 
list_coins = [('Bitcoin', 'BTC', 20193.08, 386367214848, 37844037961), 
              ('Ethereum', 'ETH', 1498.95, 183070118410, 23122015977), 
              ('Tether', 'USDT', 1.4, 67552134564, 55282835398), 
              ('USD Coin', 'USDC', 1.3, 52212969741, 8541606069), 
              ('BNB', 'BNB', 283.24, 45635342530, 1098036803)]

# %%
#connect to our created database
pgconn = psycopg2.connect(
    host='localhost',
    user='chase',
    password='yourpassword', 
    database='teamdatapoints',
    port='5433')

# %%
#cursor
pgcursor = pgconn.cursor()

# %%
#required code
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute('SELECT current_database()')

pgcursor.fetchone()
# Out:
# ('teamdatapoints',)

# %%
#drop table if it exists
pgcursor.execute('DROP TABLE IF EXISTS crypto_table')

# %%
# create table 
pgcursor.execute("""

CREATE TABLE IF NOT EXISTS crypto_table
(
    ID               SERIAL
  , NAME             VARCHAR(50) NOT NULL
  , SYMBOL           VARCHAR(20) NOT NULL
  , PRICE_USD        FLOAT
  , MARKET_CAP_USD   BIGINT
  , VOLUME_24H_USD   BIGINT
);

""")

# %%
#insert data method 1

# %%
#insert data method 2

# %%
#commit

# %%
Pandas

# %%
import pandas as pd
from sqlalchemy import create_engine

#connection string: dialect+driver://user:password@server/database
engine = create_engine('postgresql://chase:yourpassword@localhost:5433/TeamData')
#display engine info
engine
# Out:
# Engine(postgresql://chase:***@localhost:5433/TeamData)

# %%
#pass dataframes to table 
team_roster = pd.read_excel('hawks.xlsx')

#df to sql
#append, fail, repalce for the if_exists parameter
team_roster.to_sql('team_roster', engine, if_exists='replace', index=False)
team_roster
# Out:
#     Unnamed: 0         PLAYER_NAME  PLAYER_ID SEASON_ID  LEAGUE_ID  \
# 0            0       Jalen Johnson    1630552   2024-25          0
# 1            1      Keaton Wallace    1630811   2024-25          0
# 2            2         Kobe Bufkin    1641723   2024-25          0
# 3            3       Dyson Daniels    1630700   2024-25          0
# 4            4         David Roddy    1631223   2024-25          0
# 5            5  Zaccharie Risacher    1642258   2024-25          0
# 6            6          Trae Young    1629027   2024-25          0
# 7            7     De'Andre Hunter    1629631   2024-25          0
# 8            8   Bogdan Bogdanović     203992   2024-25          0
# 9            9        Clint Capela     203991   2024-25          0
# 10          10      Onyeka Okongwu    1630168   2024-25          0
# 11          11      Mouhamed Gueye    1631243   2024-25          0
# 12          12     Larry Nance Jr.    1626204   2024-25          0
# ...

# %%
# sql to df
team_roster_df = pd.read_sql_query('SELECT * FROM team_roster where ', engine)
team_roster_df
# Out:
#     Unnamed: 0         PLAYER_NAME  PLAYER_ID SEASON_ID  LEAGUE_ID  \
# 0            0       Jalen Johnson    1630552   2024-25          0
# 1            1      Keaton Wallace    1630811   2024-25          0
# 2            2         Kobe Bufkin    1641723   2024-25          0
# 3            3       Dyson Daniels    1630700   2024-25          0
# 4            4         David Roddy    1631223   2024-25          0
# 5            5  Zaccharie Risacher    1642258   2024-25          0
# 6            6          Trae Young    1629027   2024-25          0
# 7            7     De'Andre Hunter    1629631   2024-25          0
# 8            8   Bogdan Bogdanović     203992   2024-25          0
# 9            9        Clint Capela     203991   2024-25          0
# 10          10      Onyeka Okongwu    1630168   2024-25          0
# 11          11      Mouhamed Gueye    1631243   2024-25          0
# 12          12     Larry Nance Jr.    1626204   2024-25          0
# ...
