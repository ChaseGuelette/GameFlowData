# %%
def getTeamData(engine):
    with engine.connect() as conn:
        teamQuery = text("""
            WITH game_teams AS (
                SELECT DISTINCT
                    tgs.game_id,
                    tgs.season_id,
                    tgs.team_game_date as game_date,
                    -- Home team = team1 (matchup contains 'vs.')
                    MAX(CASE WHEN tgs.team_matchup LIKE '%vs.%' THEN tgs.team_id END) as team1_id,
                    -- Away team = team2 (matchup contains '@')
                    MAX(CASE WHEN tgs.team_matchup LIKE '%@%' THEN tgs.team_id END) as team2_id
                FROM team_game_stats tgs
                WHERE tgs.season_id IN ('22023', '22022')
                GROUP BY tgs.game_id, tgs.season_id, tgs.team_game_date
            )
            SELECT 
                gt.game_id,
                gt.season_id,
                gt.game_date,
                gt.team1_id,
                gt.team2_id,
                
                -- Team 1 (HOME) stats
                t1.avg_team_pts as team_pts,
                t1.avg_team_fgm as team_fgm,
                t1.avg_team_fga as team_fga,
                t1.avg_team_fg_pct as team_fg_pct,
                t1.avg_team_fg3m as team_fg3m,
                t1.avg_team_fg3a as team_fg3a,
                t1.avg_team_fg3_pct as team_fg3_pct,
                t1.avg_team_ftm as team_ftm,
                t1.avg_team_fta as team_fta,
                t1.avg_team_ft_pct as team_ft_pct,
                t1.avg_team_oreb as team_oreb,
                t1.avg_team_dreb as team_dreb,
                t1.avg_team_reb as team_reb,
                t1.avg_team_ast as team_ast,
                t1.avg_team_stl as team_stl,
                t1.avg_team_blk as team_blk,
                t1.avg_team_tov as team_tov,
                t1.avg_team_pf as team_pf,
                t1.games_in_average as team_games_in_avg,
                
                -- Team 2 (AWAY) stats
                t2.avg_team_pts as opp_pts,
                t2.avg_team_fgm as opp_fgm,
                t2.avg_team_fga as opp_fga,
                t2.avg_team_fg_pct as opp_fg_pct,
                t2.avg_team_fg3m as opp_fg3m,
                t2.avg_team_fg3a as opp_fg3a,
                t2.avg_team_fg3_pct as opp_fg3_pct,
                t2.avg_team_ftm as opp_ftm,
                t2.avg_team_fta as opp_fta,
                t2.avg_team_ft_pct as opp_ft_pct,
                t2.avg_team_oreb as opp_oreb,
                t2.avg_team_dreb as opp_dreb,
                t2.avg_team_reb as opp_reb,
                t2.avg_team_ast as opp_ast,
                t2.avg_team_stl as opp_stl,
                t2.avg_team_blk as opp_blk,
                t2.avg_team_tov as opp_tov,
                t2.avg_team_pf as opp_pf,
                t2.games_in_average as opp_games_in_avg,
                
                -- Differences (HOME - AWAY)
                t1.avg_team_pts - t2.avg_team_pts as diff_pts,
                t1.avg_team_fgm - t2.avg_team_fgm as diff_fgm,
                t1.avg_team_fga - t2.avg_team_fga as diff_fga,
                t1.avg_team_fg_pct - t2.avg_team_fg_pct as diff_fg_pct,
                t1.avg_team_fg3m - t2.avg_team_fg3m as diff_fg3m,
                t1.avg_team_fg3a - t2.avg_team_fg3a as diff_fg3a,
                t1.avg_team_fg3_pct - t2.avg_team_fg3_pct as diff_fg3_pct,
                t1.avg_team_ftm - t2.avg_team_ftm as diff_ftm,
                t1.avg_team_fta - t2.avg_team_fta as diff_fta,
                t1.avg_team_ft_pct - t2.avg_team_ft_pct as diff_ft_pct,
                t1.avg_team_oreb - t2.avg_team_oreb as diff_oreb,
                t1.avg_team_dreb - t2.avg_team_dreb as diff_dreb,
                t1.avg_team_reb - t2.avg_team_reb as diff_reb,
                t1.avg_team_ast - t2.avg_team_ast as diff_ast,
                t1.avg_team_stl - t2.avg_team_stl as diff_stl,
                t1.avg_team_blk - t2.avg_team_blk as diff_blk,
                t1.avg_team_tov - t2.avg_team_tov as diff_tov,
                t1.avg_team_pf - t2.avg_team_pf as diff_pf
                
            FROM game_teams gt
            JOIN team_average_game_stats t1 ON gt.game_id = t1.game_id AND gt.team1_id = t1.team_id
            JOIN team_average_game_stats t2 ON gt.game_id = t2.game_id AND gt.team2_id = t2.team_id
            WHERE t1.games_in_average >= 5
              AND t2.games_in_average >= 5
            ORDER BY gt.game_date, gt.game_id;
        """)
        return pd.read_sql(teamQuery, conn)


def getPlayerData(engine):
    with engine.connect() as conn:
        playerQuery = text("""
            WITH game_teams AS (
                SELECT DISTINCT
                    tgs.game_id,
                    tgs.season_id,
                    -- Home team = team1 (matchup contains 'vs.')
                    MAX(CASE WHEN tgs.team_matchup LIKE '%vs.%' THEN tgs.team_id END) as team1_id,
                    -- Away team = team2 (matchup contains '@')
                    MAX(CASE WHEN tgs.team_matchup LIKE '%@%' THEN tgs.team_id END) as team2_id
                FROM team_game_stats tgs
                WHERE tgs.season_id IN ('22023', '22022')
                GROUP BY tgs.game_id, tgs.season_id
            ),
            ranked_players AS (
                SELECT 
                    pgs.game_id,
                    pgs.season_id,
                    pgs.team_id,
                    pgs.player_id,
                    p.player_name,
                    pgs.avg_min,
                    pgs.avg_pts,
                    pgs.avg_fgm,
                    pgs.avg_fga,
                    pgs.avg_fg_pct,
                    pgs.avg_fg3m,
                    pgs.avg_fg3a,
                    pgs.avg_fg3_pct,
                    pgs.avg_ftm,
                    pgs.avg_fta,
                    pgs.avg_ft_pct,
                    pgs.avg_oreb,
                    pgs.avg_dreb,
                    pgs.avg_reb,
                    pgs.avg_ast,
                    pgs.avg_stl,
                    pgs.avg_blk,
                    pgs.avg_tov,
                    pgs.avg_pf,
                    pgs.avg_plus_minus,
                    pgs.games_in_average,
                    ROW_NUMBER() OVER (PARTITION BY pgs.game_id, pgs.team_id ORDER BY pgs.avg_min DESC) as player_rank
                FROM player_average_game_stats pgs
                JOIN players p ON pgs.player_id = p.player_id
                WHERE pgs.avg_min > 0
            )
            -- HOME team players (team1 = 'team')
            SELECT 
                gt.game_id,
                gt.season_id,
                'team' as player_team_type,
                gt.team1_id as team_id,
                rp.player_rank,
                rp.player_id,
                rp.player_name,
                rp.avg_min,
                rp.avg_pts,
                rp.avg_fgm,
                rp.avg_fga,
                rp.avg_fg_pct,
                rp.avg_fg3m,
                rp.avg_fg3a,
                rp.avg_fg3_pct,
                rp.avg_ftm,
                rp.avg_fta,
                rp.avg_ft_pct,
                rp.avg_oreb,
                rp.avg_dreb,
                rp.avg_reb,
                rp.avg_ast,
                rp.avg_stl,
                rp.avg_blk,
                rp.avg_tov,
                rp.avg_pf,
                rp.avg_plus_minus,
                rp.games_in_average
            FROM game_teams gt
            JOIN ranked_players rp ON gt.game_id = rp.game_id AND gt.team1_id = rp.team_id
            WHERE rp.player_rank <= 10
            
            UNION ALL
            
            -- AWAY team players (team2 = 'opp')
            SELECT 
                gt.game_id,
                gt.season_id,
                'opp' as player_team_type,
                gt.team2_id as team_id,
                rp.player_rank,
                rp.player_id,
                rp.player_name,
                rp.avg_min,
                rp.avg_pts,
                rp.avg_fgm,
                rp.avg_fga,
                rp.avg_fg_pct,
                rp.avg_fg3m,
                rp.avg_fg3a,
                rp.avg_fg3_pct,
                rp.avg_ftm,
                rp.avg_fta,
                rp.avg_ft_pct,
                rp.avg_oreb,
                rp.avg_dreb,
                rp.avg_reb,
                rp.avg_ast,
                rp.avg_stl,
                rp.avg_blk,
                rp.avg_tov,
                rp.avg_pf,
                rp.avg_plus_minus,
                rp.games_in_average
            FROM game_teams gt
            JOIN ranked_players rp ON gt.game_id = rp.game_id AND gt.team2_id = rp.team_id
            WHERE rp.player_rank <= 10
            
            ORDER BY game_id, player_team_type, player_rank;
        """)
        return pd.read_sql(playerQuery, conn)

# %%
def remove_leakage(df, drop_cols):
    cols_to_drop = [c for c in df.columns if c in drop_cols]
    return df.drop(columns=cols_to_drop, errors="ignore")

# %%
from sklearn.feature_selection import VarianceThreshold


def variance_filter(df, target="target_win", threshold=0.001):
    """
    Remove features with variance below threshold.
    Raises error if NaN values are present - handle them upstream.
    """
    if target not in df.columns:
        raise ValueError(f"Target column '{target}' not found in DataFrame")

    numeric_df = df.drop(columns=[target]).select_dtypes(include=["int64", "float64"])

    if numeric_df.empty:
        print("⚠️ Warning: No numeric features to filter")
        return df

    # Check for NaN values - must be handled upstream
    nan_counts = numeric_df.isna().sum()
    cols_with_nan = nan_counts[nan_counts > 0]
    if len(cols_with_nan) > 0:
        raise ValueError(
            f"Found NaN values in {len(cols_with_nan)} columns. "
            f"Handle missing data before feature selection.\n"
            f"Columns with NaN: {cols_with_nan.index.tolist()[:10]}{'...' if len(cols_with_nan) > 10 else ''}"
        )

    selector = VarianceThreshold(threshold=threshold)
    selector.fit(numeric_df)

    low_variance = numeric_df.columns[~selector.get_support()]
    print(f"🔎 Low-variance removed ({len(low_variance)} features):", low_variance.tolist())

    # Drop low variance columns and return with target intact
    cols_to_keep = [col for col in df.columns if col not in low_variance]
    return df[cols_to_keep]

# %%
import numpy as np


def correlation_pruning(df, target="target_win", threshold=0.90):
    """
    Remove highly correlated features (keeps first of each correlated pair).
    Raises error if NaN values are present - handle them upstream.
    """
    if target not in df.columns:
        raise ValueError(f"Target column '{target}' not found in DataFrame")

    numeric_df = df.drop(columns=[target]).select_dtypes(include=["int64", "float64"])

    if numeric_df.empty or len(numeric_df.columns) < 2:
        print("⚠️ Warning: Not enough numeric features to check correlations")
        return df

    # Check for NaN values - must be handled upstream
    nan_counts = numeric_df.isna().sum()
    cols_with_nan = nan_counts[nan_counts > 0]
    if len(cols_with_nan) > 0:
        raise ValueError(
            f"Found NaN values in {len(cols_with_nan)} columns. "
            f"Handle missing data before feature selection.\n"
            f"Columns with NaN: {cols_with_nan.index.tolist()[:10]}{'...' if len(cols_with_nan) > 10 else ''}"
        )

    corr = numeric_df.corr().abs()

    # Upper triangle mask
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    print(f"🔎 High-correlation removed ({len(to_drop)} features):", to_drop)

    cols_to_keep = [col for col in df.columns if col not in to_drop]
    return df[cols_to_keep]

# %%
import pandas as pd
from sklearn.feature_selection import f_classif


def anova_scores(df, target="target_win"):
    """
    Calculate ANOVA F-scores for feature importance ranking.
    Raises error if NaN values are present - handle them upstream.
    """
    if target not in df.columns:
        raise ValueError(f"Target column '{target}' not found in DataFrame")

    X = df.drop(columns=[target]).select_dtypes(include=["int64", "float64"])
    y = df[target]

    if X.empty:
        raise ValueError("No numeric features available for ANOVA scoring")

    # Check for NaN values - must be handled upstream
    nan_counts = X.isna().sum()
    cols_with_nan = nan_counts[nan_counts > 0]
    if len(cols_with_nan) > 0:
        raise ValueError(
            f"Found NaN values in {len(cols_with_nan)} columns. "
            f"Handle missing data before feature selection.\n"
            f"Columns with NaN: {cols_with_nan.index.tolist()[:10]}{'...' if len(cols_with_nan) > 10 else ''}"
        )

    if y.isna().any():
        raise ValueError("Target column contains NaN values. Handle missing data before feature selection.")

    f_scores, p_vals = f_classif(X, y)

    anova_df = (
        pd.DataFrame({"feature": X.columns, "f_score": f_scores})
        .sort_values("f_score", ascending=False)
        .reset_index(drop=True)
    )

    print("🏅 Top ANOVA features:")
    print(anova_df.head(20))
    return anova_df

# %%
from sklearn.feature_selection import mutual_info_classif


def mi_scores(df, target="target_win"):
    """
    Calculate Mutual Information scores for feature importance ranking.
    Raises error if NaN values are present - handle them upstream.
    """
    if target not in df.columns:
        raise ValueError(f"Target column '{target}' not found in DataFrame")

    X = df.drop(columns=[target]).select_dtypes(include=["int64", "float64"])
    y = df[target]

    if X.empty:
        raise ValueError("No numeric features available for MI scoring")

    # Check for NaN values - must be handled upstream
    nan_counts = X.isna().sum()
    cols_with_nan = nan_counts[nan_counts > 0]
    if len(cols_with_nan) > 0:
        raise ValueError(
            f"Found NaN values in {len(cols_with_nan)} columns. "
            f"Handle missing data before feature selection.\n"
            f"Columns with NaN: {cols_with_nan.index.tolist()[:10]}{'...' if len(cols_with_nan) > 10 else ''}"
        )

    if y.isna().any():
        raise ValueError("Target column contains NaN values. Handle missing data before feature selection.")

    mi = mutual_info_classif(X, y)

    mi_df = (
        pd.DataFrame({"feature": X.columns, "mi_score": mi})
        .sort_values("mi_score", ascending=False)
        .reset_index(drop=True)
    )

    print("🏅 Top MI features:")
    print(mi_df.head(20))
    return mi_df

# %%
def flatten_player_data(player_df):
    """
    Pivot player data from long format (multiple rows per game)
    to wide format (one row per game with player stats as columns).

    - Adds player count features (roster depth signal)
    - Fills missing player slots with 0

    Returns: DataFrame with one row per game_id
    """
    # Define which columns are stats (exclude identifiers)
    stat_cols = [
        "avg_min",
        "avg_pts",
        "avg_fgm",
        "avg_fga",
        "avg_fg_pct",
        "avg_fg3m",
        "avg_fg3a",
        "avg_fg3_pct",
        "avg_ftm",
        "avg_fta",
        "avg_ft_pct",
        "avg_oreb",
        "avg_dreb",
        "avg_reb",
        "avg_ast",
        "avg_stl",
        "avg_blk",
        "avg_tov",
        "avg_pf",
        "avg_plus_minus",
        "games_in_average",
    ]

    # Count players per team per game (roster depth signal)
    player_counts = player_df.groupby(["game_id", "player_team_type"]).size().unstack(fill_value=0)
    player_counts.columns = ["opp_player_count", "team_player_count"]
    player_counts = player_counts.reset_index()

    # Report on player count distribution
    print("📊 Player count distribution:")
    print(
        f"   Team players:  min={player_counts['team_player_count'].min()}, "
        f"max={player_counts['team_player_count'].max()}, "
        f"median={player_counts['team_player_count'].median():.0f}"
    )
    print(
        f"   Opp players:   min={player_counts['opp_player_count'].min()}, "
        f"max={player_counts['opp_player_count'].max()}, "
        f"median={player_counts['opp_player_count'].median():.0f}"
    )

    # Create a column name for each player stat
    # Format: {team_type}_player{rank}_{stat}
    player_df = player_df.copy()
    player_df["player_prefix"] = player_df["player_team_type"] + "_player" + player_df["player_rank"].astype(str)

    # Pivot: each (game_id, player_prefix, stat) becomes a column
    pivoted_parts = []

    for stat in stat_cols:
        stat_pivot = player_df.pivot_table(index="game_id", columns="player_prefix", values=stat, aggfunc="first")
        # Rename columns to include stat name
        stat_pivot.columns = [f"{col}_{stat}" for col in stat_pivot.columns]
        pivoted_parts.append(stat_pivot)

    # Concatenate all stat pivots horizontally
    flattened = pd.concat(pivoted_parts, axis=1)

    # Reset index to make game_id a column again
    flattened = flattened.reset_index()

    # Add player count features (before filling NaN)
    flattened = flattened.merge(player_counts, on="game_id", how="left")

    # Also add difference in roster depth
    flattened["diff_player_count"] = flattened["team_player_count"] - flattened["opp_player_count"]

    # Fill missing player slots with 0 (player didn't play = 0 contribution)
    nan_count_before = flattened.isna().sum().sum()
    flattened = flattened.fillna(0)

    print(f"✅ Filled {nan_count_before} NaN values with 0 (missing player slots)")
    print("   Added features: team_player_count, opp_player_count, diff_player_count")

    return flattened

# %%
def add_target_variable(ml_df, engine):
    """
    Add the target variable (whether team1 won) to the dataset.
    """
    with engine.connect() as conn:
        # Get actual game results for all teams
        results_query = text("""
            SELECT 
                game_id,
                team_id,
                team_pts
            FROM team_game_stats
            WHERE season_id IN ('22023', '22022')
        """)
        results_df = pd.read_sql(results_query, conn)

    # Join to get both teams' actual scores
    team1_results = results_df.rename(columns={"team_id": "team1_id", "team_pts": "team1_actual_pts"})
    team2_results = results_df.rename(columns={"team_id": "team2_id", "team_pts": "team2_actual_pts"})

    ml_df = ml_df.merge(
        team1_results[["game_id", "team1_id", "team1_actual_pts"]],
        on=["game_id", "team1_id"],
        how="left",
    )
    ml_df = ml_df.merge(
        team2_results[["game_id", "team2_id", "team2_actual_pts"]],
        on=["game_id", "team2_id"],
        how="left",
    )

    # Create target: 1 if team1 won, 0 if team2 won
    ml_df["target_win"] = (ml_df["team1_actual_pts"] > ml_df["team2_actual_pts"]).astype(int)

    # Drop the actual score columns (they're leakage)
    ml_df = ml_df.drop(columns=["team1_actual_pts", "team2_actual_pts"])

    return ml_df

# %%
LEAKAGE_COLS = [
    "game_id",
    "season_id",
    "game_date",
    "team1_id",
    "team2_id",
    "team_games_in_avg",
    "opp_games_in_avg",
]


def preprocess_features_detailed(df, target="target_win"):
    """
    Full feature selection pipeline with intermediate results.

    Raises ValueError if NaN values are detected - handle missing data upstream.
    """
    print("\n🚀 Starting feature selection pipeline...\n")

    if target not in df.columns:
        raise ValueError(f"Target column '{target}' not found in DataFrame")

    # Check for NaN values upfront
    nan_counts = df.isna().sum()
    cols_with_nan = nan_counts[nan_counts > 0]
    if len(cols_with_nan) > 0:
        raise ValueError(
            f"DataFrame contains NaN values in {len(cols_with_nan)} columns. "
            f"Handle missing data before running feature selection.\n"
            f"Columns with NaN: {cols_with_nan.index.tolist()[:10]}{'...' if len(cols_with_nan) > 10 else ''}\n"
            f"Total NaN values: {nan_counts.sum()}"
        )

    # Store original
    original_df = df.copy()

    # 1. Remove leakage columns
    leakage_found = [col for col in LEAKAGE_COLS if col in df.columns]
    df = df.drop(columns=leakage_found)
    print(f"✓ Removed {len(leakage_found)} leakage columns: {leakage_found}")

    # 2. Drop non-numeric leftover columns (keep target)
    non_numeric = df.select_dtypes(exclude=["int64", "float64", "float32"]).columns.tolist()
    non_numeric = [col for col in non_numeric if col != target]
    if non_numeric:
        df = df.drop(columns=non_numeric)
        print(f"✓ Removed {len(non_numeric)} non-numeric columns: {non_numeric}")
    else:
        print("✓ All remaining columns are numeric")

    # 3. Variance filtering
    after_variance = variance_filter(df, target=target)

    # 4. Correlation pruning
    after_correlation = correlation_pruning(after_variance, target=target)

    # 5. Relevance rankings
    anova_df = anova_scores(after_correlation, target=target)
    mi_df = mi_scores(after_correlation, target=target)

    print("\n✅ Feature selection complete!")
    print(f"   Started with {len(original_df.columns) - 1} features")
    print(f"   Ended with {len(after_correlation.columns) - 1} features")

    # Return everything for analysis
    return {
        "original": original_df,
        "after_variance": after_variance,
        "after_correlation": after_correlation,
        "final": after_correlation,
        "anova": anova_df,
        "mi": mi_df,
    }

# %%
# Analysis and visualization functions

import matplotlib.pyplot as plt
import seaborn as sns


def analyze_feature_selection_results(original_df, filtered_df, anova_df, mi_df):
    """
    Comprehensive analysis of feature selection results.
    Shows what was dropped, correlations, and feature importance.
    """
    print("=" * 80)
    print("FEATURE SELECTION SUMMARY")
    print("=" * 80)

    # 1. Overall reduction
    original_features = [col for col in original_df.columns if col != "target_win"]
    final_features = [col for col in filtered_df.columns if col != "target_win"]

    print("\n📊 FEATURE REDUCTION:")
    print(f"   Original features: {len(original_features)}")
    print(f"   Final features: {len(final_features)}")
    print(
        f"   Reduction: {len(original_features) - len(final_features)} features ({(1 - len(final_features) / len(original_features)) * 100:.1f}%)"
    )

    # 2. Top features by ANOVA
    print("\n🏆 TOP 20 FEATURES (ANOVA F-Score):")
    print(anova_df.head(20).to_string(index=False))

    # 3. Top features by Mutual Information
    print("\n🏆 TOP 20 FEATURES (Mutual Information):")
    print(mi_df.head(20).to_string(index=False))

    # 4. Feature categories breakdown
    print("\n📁 FEATURE CATEGORIES REMAINING:")
    analyze_feature_categories(final_features)

    return final_features


def analyze_feature_categories(features):
    """
    Break down features by category (team, opp, diff, player stats).
    """
    categories = {
        "team_stats": [f for f in features if f.startswith("team_") and not f.startswith("team_player")],
        "opp_stats": [f for f in features if f.startswith("opp_") and not f.startswith("opp_player")],
        "diff_stats": [f for f in features if f.startswith("diff_")],
        "team_player_stats": [f for f in features if f.startswith("team_player")],
        "opp_player_stats": [f for f in features if f.startswith("opp_player")],
    }

    for cat, feats in categories.items():
        print(f"   {cat:20s}: {len(feats):4d} features")


def plot_correlation_heatmap(df, top_n=30, figsize=(16, 14)):
    """
    Plot correlation heatmap for top N features by ANOVA score.
    """
    # Get top features
    X = df.drop(columns=["target_win"]).select_dtypes(include=["int64", "float64"])
    y = df["target_win"]

    if X.empty:
        print("⚠️ No numeric features available for correlation heatmap")
        return

    from sklearn.feature_selection import f_classif

    f_scores, _ = f_classif(X, y)

    top_indices = np.argsort(f_scores)[-top_n:]
    top_features = X.columns[top_indices].tolist()

    # Calculate correlation matrix
    corr = df[top_features + ["target_win"]].corr()

    # Plot
    plt.figure(figsize=figsize)
    sns.heatmap(
        corr,
        cmap="RdBu_r",
        center=0,
        vmin=-1,
        vmax=1,
        square=True,
        linewidths=0.5,
        cbar_kws={"shrink": 0.8},
    )
    plt.title(f"Correlation Heatmap: Top {top_n} Features + Target", fontsize=14, pad=20)
    plt.tight_layout()
    plt.show()

    print("\n🔥 HIGHEST CORRELATIONS WITH TARGET:")
    target_corr = corr["target_win"].drop("target_win").abs().sort_values(ascending=False)
    print(target_corr.head(15))


def analyze_dropped_features(original_df, after_variance_df, after_correlation_df):
    """
    Detailed analysis of what was dropped at each step.
    """
    print("\n" + "=" * 80)
    print("DETAILED DROPOUT ANALYSIS")
    print("=" * 80)

    original_features = set(original_df.columns) - {"target_win"}
    after_variance = set(after_variance_df.columns) - {"target_win"}
    after_correlation = set(after_correlation_df.columns) - {"target_win"}

    # Get numeric columns from original for variance calculation
    numeric_cols = original_df.select_dtypes(include=["int64", "float64", "float32"]).columns

    # Variance filter dropouts
    variance_dropped = original_features - after_variance
    print(f"\n❌ DROPPED BY VARIANCE FILTER ({len(variance_dropped)} features):")
    if variance_dropped:
        for feat in sorted(variance_dropped):
            if feat in numeric_cols:
                var = original_df[feat].var()
                print(f"   {feat:50s} (variance: {var:.6f})")
            else:
                print(f"   {feat:50s} (non-numeric, removed)")
    else:
        print("   None")

    # Correlation filter dropouts
    correlation_dropped = after_variance - after_correlation
    print(f"\n❌ DROPPED BY CORRELATION FILTER ({len(correlation_dropped)} features):")
    if correlation_dropped:
        for feat in sorted(correlation_dropped):
            print(f"   {feat}")
    else:
        print("   None")


def plot_feature_importance_comparison(anova_df, mi_df, top_n=20):
    """
    Compare ANOVA and MI rankings side-by-side.
    """
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))

    # ANOVA scores
    top_anova = anova_df.head(top_n)
    axes[0].barh(range(len(top_anova)), top_anova["f_score"])
    axes[0].set_yticks(range(len(top_anova)))
    axes[0].set_yticklabels(top_anova["feature"], fontsize=8)
    axes[0].invert_yaxis()
    axes[0].set_xlabel("F-Score")
    axes[0].set_title(f"Top {top_n} Features: ANOVA F-Score")
    axes[0].grid(axis="x", alpha=0.3)

    # MI scores
    top_mi = mi_df.head(top_n)
    axes[1].barh(range(len(top_mi)), top_mi["mi_score"])
    axes[1].set_yticks(range(len(top_mi)))
    axes[1].set_yticklabels(top_mi["feature"], fontsize=8)
    axes[1].invert_yaxis()
    axes[1].set_xlabel("MI Score")
    axes[1].set_title(f"Top {top_n} Features: Mutual Information")
    axes[1].grid(axis="x", alpha=0.3)

    plt.tight_layout()
    plt.show()


def analyze_player_vs_team_importance(anova_df, mi_df):
    """
    Compare importance of player stats vs team stats.
    """
    print("\n" + "=" * 80)
    print("PLAYER VS TEAM FEATURE IMPORTANCE")
    print("=" * 80)

    def categorize_and_score(df, score_col):
        df = df.copy()
        df["category"] = df["feature"].apply(
            lambda x: "team_player"
            if "team_player" in x
            else "opp_player"
            if "opp_player" in x
            else "team_stats"
            if x.startswith("team_")
            else "opp_stats"
            if x.startswith("opp_")
            else "diff_stats"
            if x.startswith("diff_")
            else "other"
        )
        return df.groupby("category")[score_col].agg(["mean", "sum", "count"])

    print("\n📊 BY ANOVA F-SCORE:")
    anova_summary = categorize_and_score(anova_df, "f_score")
    print(anova_summary.sort_values("mean", ascending=False))

    print("\n📊 BY MUTUAL INFORMATION:")
    mi_summary = categorize_and_score(mi_df, "mi_score")
    print(mi_summary.sort_values("mean", ascending=False))

# %%
import os

from dotenv import load_dotenv
from sqlalchemy import create_engine, text

load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL")
engine = create_engine(DATABASE_URL)

ml_df = create_ml_dataset(engine)
# Out:
# 📥 Fetching team data...
#    Retrieved 2300 team game records
# 📥 Fetching player data...
#    Retrieved 46836 player game records
# 🔄 Flattening player data...
# 📊 Player count distribution:
#    Team players:  min=0, max=10, median=10
#    Opp players:   min=0, max=10, median=10
# ✅ Filled 37464 NaN values with 0 (missing player slots)
#    Added features: team_player_count, opp_player_count, diff_player_count
# ✅ Dataset shape: (2271, 484)
#    - 2271 games
#    - 484 total features

# %%
# 2. Add target variable
ml_df = add_target_variable(ml_df, engine)
print(f"🏠 Home team (team1) win rate: {ml_df['target_win'].mean():.1%}")
# Out:
# 🏠 Home team (team1) win rate: 56.0%

# %%
# 3. Run detailed feature selection with comprehensive analysis
results = preprocess_features_detailed(ml_df)

# Comprehensive analysis
final_features = analyze_feature_selection_results(
    results["original"], results["final"], results["anova"], results["mi"]
)

# Detailed dropout analysis
analyze_dropped_features(results["original"], results["after_variance"], results["after_correlation"])

# Player vs Team comparison
analyze_player_vs_team_importance(results["anova"], results["mi"])

# Visualizations
plot_feature_importance_comparison(results["anova"], results["mi"], top_n=25)
plot_correlation_heatmap(results["final"], top_n=30)

# Store final filtered dataframe
filtered_df = results["final"]
# Out:
# 🚀 Starting feature selection pipeline...
#
# ✓ Removed 7 leakage columns: ['game_id', 'season_id', 'game_date', 'team1_id', 'team2_id', 'team_games_in_avg', 'opp_games_in_avg']
# ✓ All remaining columns are numeric
# 🔎 Low-variance removed (8 features): ['team_fg_pct', 'team_fg3_pct', 'team_ft_pct', 'opp_fg_pct', 'opp_fg3_pct', 'opp_ft_pct', 'diff_fg_pct', 'diff_fg3_pct']
# 🔎 High-correlation removed (107 features): ['team_fg3a', 'team_fta', 'opp_fg3a', 'opp_fta', 'diff_fg3a', 'diff_fta', 'opp_player1_avg_fgm', 'opp_player10_avg_fgm', 'opp_player2_avg_fgm', 'opp_player3_avg_fgm', 'opp_player4_avg_fgm', 'opp_player5_avg_fgm', 'opp_player6_avg_fgm', 'opp_player7_avg_fgm', 'opp_player8_avg_fgm', 'opp_player9_avg_fgm', 'team_player1_avg_fgm', 'team_player10_avg_fgm', 'team_player2_avg_fgm', 'team_player3_avg_fgm', 'team_player4_avg_fgm', 'team_player5_avg_fgm', 'team_player6_avg_fgm', 'team_player7_avg_fgm', 'team_player8_avg_fgm', 'team_player9_avg_fgm', 'opp_player10_avg_fga', 'opp_player2_avg_fga', 'opp_player3_avg_fga', 'opp_player4_avg_fga', 'opp_player5_avg_fga', 'opp_player6_avg_fga', 'opp_player8_avg_fga', 'opp_player9_avg_fga', 'team_player10_avg_fga', 'team_player2_avg_fga', 'team_player3_avg_fga', 'team_player4_avg_fga', 'team_player5_avg_fga', 'team_player6_avg_fga', 'team_player9_avg_fga', 'opp_player1_avg_fg3a', 'opp_player10_avg_fg3a', 'opp_player2_avg_fg3a', 'opp_player3_avg_fg3a', 'opp_player4_avg_fg3a', 'opp_player5_avg_fg3a', 'opp_player6_avg_fg3a', 'opp_player7_avg_fg3a', 'opp_player8_avg_fg3a', 'opp_player9_avg_fg3a', 'team_player1_avg_fg3a', 'team_player10_avg_fg3a', 'team_player2_avg_fg3a', 'team_player3_avg_fg3a', 'team_player4_avg_fg3a', 'team_player5_avg_fg3a', 'team_player6_avg_fg3a', 'team_player7_avg_fg3a', 'team_player8_avg_fg3a', 'team_player9_avg_fg3a', 'opp_player1_avg_fta', 'opp_player10_avg_fta', 'opp_player2_avg_fta', 'opp_player3_avg_fta', 'opp_player4_avg_fta', 'opp_player5_avg_fta', 'opp_player6_avg_fta', 'opp_player7_avg_fta', 'opp_player8_avg_fta', 'opp_player9_avg_fta', 'team_player1_avg_fta', 'team_player10_avg_fta', 'team_player2_avg_fta', 'team_player3_avg_fta', 'team_player4_avg_fta', 'team_player5_avg_fta', 'team_player6_avg_fta', 'team_player7_avg_fta', 'team_player8_avg_fta', 'team_player9_avg_fta', 'opp_player10_avg_ft_pct', 'team_player10_avg_ft_pct', 'opp_player1_avg_reb', 'opp_player10_avg_reb', 'opp_player2_avg_reb', 'opp_player3_avg_reb', 'opp_player4_avg_reb', 'opp_player5_avg_reb', 'opp_player6_avg_reb', 'opp_player7_avg_reb', 'opp_player8_avg_reb', 'opp_player9_avg_reb', 'team_player1_avg_reb', 'team_player10_avg_reb', 'team_player2_avg_reb', 'team_player3_avg_reb', 'team_player4_avg_reb', 'team_player5_avg_reb', 'team_player6_avg_reb', 'team_player7_avg_reb', 'team_player8_avg_reb', 'team_player9_avg_reb', 'opp_player2_games_in_average', 'opp_player4_games_in_average', 'team_player2_games_in_average', 'team_player4_games_in_average']
# 🏅 Top ANOVA features:
#                         feature     f_score
# 0   team_player2_avg_plus_minus  113.412207
# 1   team_player1_avg_plus_minus  109.136199
# 2   team_player3_avg_plus_minus   92.380490
# 3    opp_player1_avg_plus_minus   88.195962
# 4    opp_player2_avg_plus_minus   72.769401
# 5   team_player5_avg_plus_minus   71.787443
# 6   team_player4_avg_plus_minus   71.653950
# 7                     diff_dreb   69.732606
# 8                      diff_tov   65.613405
# 9                      diff_pts   55.446535
# 10   opp_player3_avg_plus_minus   54.775722
# 11  team_player7_avg_plus_minus   45.386285
# 12                    team_dreb   44.628202
# 13   opp_player8_avg_plus_minus   42.919268
# 14          opp_player1_avg_min   42.615783
# 15         team_player1_avg_pts   42.521771
# 16   opp_player5_avg_plus_minus   39.399158
# 17   opp_player4_avg_plus_minus   39.164266
# 18          opp_player1_avg_pts   39.033592
# 19         team_player2_avg_min   37.930582
# 🏅 Top MI features:
#                         feature  mi_score
# 0          opp_player1_avg_dreb  0.037849
# 1           opp_player5_avg_min  0.034794
# 2   team_player2_avg_plus_minus  0.030776
# 3    opp_player1_avg_plus_minus  0.030565
# 4          opp_player10_avg_ftm  0.030368
# 5       team_player8_avg_fg_pct  0.030208
# 6   team_player1_avg_plus_minus  0.030080
# 7   team_player5_avg_plus_minus  0.029672
# 8         team_player4_avg_dreb  0.029575
# 9           opp_player4_avg_ftm  0.029167
# 10  team_player3_avg_plus_minus  0.029075
# 11         team_player1_avg_pts  0.028935
# 12         opp_player4_avg_oreb  0.028661
# 13          opp_player6_avg_ftm  0.028638
# 14                     team_pts  0.028621
# 15          team_player4_avg_pf  0.027629
# 16        team_player2_avg_fg3m  0.026989
# 17          opp_player2_avg_blk  0.025752
# 18   opp_player9_avg_plus_minus  0.025182
# 19          opp_player8_avg_tov  0.024678
#
# ✅ Feature selection complete!
#    Started with 484 features
#    Ended with 362 features
# ================================================================================
# FEATURE SELECTION SUMMARY
# ================================================================================
#
# 📊 FEATURE REDUCTION:
#    Original features: 484
#    Final features: 362
#    Reduction: 122 features (25.2%)
#
# 🏆 TOP 20 FEATURES (ANOVA F-Score):
#                     feature    f_score
# team_player2_avg_plus_minus 113.412207
# team_player1_avg_plus_minus 109.136199
# team_player3_avg_plus_minus  92.380490
#  opp_player1_avg_plus_minus  88.195962
#  opp_player2_avg_plus_minus  72.769401
# team_player5_avg_plus_minus  71.787443
# team_player4_avg_plus_minus  71.653950
#                   diff_dreb  69.732606
#                    diff_tov  65.613405
#                    diff_pts  55.446535
#  opp_player3_avg_plus_minus  54.775722
# team_player7_avg_plus_minus  45.386285
#                   team_dreb  44.628202
#  opp_player8_avg_plus_minus  42.919268
#         opp_player1_avg_min  42.615783
#        team_player1_avg_pts  42.521771
#  opp_player5_avg_plus_minus  39.399158
#  opp_player4_avg_plus_minus  39.164266
#         opp_player1_avg_pts  39.033592
#        team_player2_avg_min  37.930582
#
# 🏆 TOP 20 FEATURES (Mutual Information):
#                     feature  mi_score
#        opp_player1_avg_dreb  0.037849
#         opp_player5_avg_min  0.034794
# team_player2_avg_plus_minus  0.030776
#  opp_player1_avg_plus_minus  0.030565
#        opp_player10_avg_ftm  0.030368
#     team_player8_avg_fg_pct  0.030208
# team_player1_avg_plus_minus  0.030080
# team_player5_avg_plus_minus  0.029672
#       team_player4_avg_dreb  0.029575
#         opp_player4_avg_ftm  0.029167
# team_player3_avg_plus_minus  0.029075
#        team_player1_avg_pts  0.028935
#        opp_player4_avg_oreb  0.028661
#         opp_player6_avg_ftm  0.028638
#                    team_pts  0.028621
#         team_player4_avg_pf  0.027629
#       team_player2_avg_fg3m  0.026989
#         opp_player2_avg_blk  0.025752
#  opp_player9_avg_plus_minus  0.025182
#         opp_player8_avg_tov  0.024678
#
# 📁 FEATURE CATEGORIES REMAINING:
#    team_stats          :   13 features
#    opp_stats           :   13 features
#    diff_stats          :   15 features
#    team_player_stats   :  161 features
#    opp_player_stats    :  160 features
#
# ================================================================================
# DETAILED DROPOUT ANALYSIS
# ================================================================================
#
# ❌ DROPPED BY VARIANCE FILTER (15 features):
#    diff_fg3_pct                                       (variance: 0.000715)
#    diff_fg_pct                                        (variance: 0.000549)
#    game_date                                          (non-numeric, removed)
#    game_id                                            (non-numeric, removed)
#    opp_fg3_pct                                        (variance: 0.000362)
#    opp_fg_pct                                         (variance: 0.000280)
#    opp_ft_pct                                         (variance: 0.000990)
#    opp_games_in_avg                                   (variance: 482.597094)
#    season_id                                          (non-numeric, removed)
#    team1_id                                           (variance: 75.147026)
#    team2_id                                           (variance: 74.914907)
#    team_fg3_pct                                       (variance: 0.000370)
#    team_fg_pct                                        (variance: 0.000280)
#    team_ft_pct                                        (variance: 0.000971)
#    team_games_in_avg                                  (variance: 482.518864)
#
# ❌ DROPPED BY CORRELATION FILTER (107 features):
#    diff_fg3a
#    diff_fta
#    opp_fg3a
#    opp_fta
#    opp_player10_avg_fg3a
#    opp_player10_avg_fga
#    opp_player10_avg_fgm
#    opp_player10_avg_ft_pct
#    opp_player10_avg_fta
#    opp_player10_avg_reb
#    opp_player1_avg_fg3a
#    opp_player1_avg_fgm
#    opp_player1_avg_fta
#    opp_player1_avg_reb
#    opp_player2_avg_fg3a
#    opp_player2_avg_fga
#    opp_player2_avg_fgm
#    opp_player2_avg_fta
#    opp_player2_avg_reb
#    opp_player2_games_in_average
#    opp_player3_avg_fg3a
#    opp_player3_avg_fga
#    opp_player3_avg_fgm
#    opp_player3_avg_fta
#    opp_player3_avg_reb
#    opp_player4_avg_fg3a
#    opp_player4_avg_fga
#    opp_player4_avg_fgm
#    opp_player4_avg_fta
#    opp_player4_avg_reb
#    opp_player4_games_in_average
#    opp_player5_avg_fg3a
#    opp_player5_avg_fga
#    opp_player5_avg_fgm
#    opp_player5_avg_fta
#    opp_player5_avg_reb
#    opp_player6_avg_fg3a
#    opp_player6_avg_fga
#    opp_player6_avg_fgm
#    opp_player6_avg_fta
#    opp_player6_avg_reb
#    opp_player7_avg_fg3a
#    opp_player7_avg_fgm
#    opp_player7_avg_fta
#    opp_player7_avg_reb
#    opp_player8_avg_fg3a
#    opp_player8_avg_fga
#    opp_player8_avg_fgm
#    opp_player8_avg_fta
#    opp_player8_avg_reb
#    opp_player9_avg_fg3a
#    opp_player9_avg_fga
#    opp_player9_avg_fgm
#    opp_player9_avg_fta
#    opp_player9_avg_reb
#    team_fg3a
#    team_fta
#    team_player10_avg_fg3a
#    team_player10_avg_fga
#    team_player10_avg_fgm
#    team_player10_avg_ft_pct
#    team_player10_avg_fta
#    team_player10_avg_reb
#    team_player1_avg_fg3a
#    team_player1_avg_fgm
#    team_player1_avg_fta
#    team_player1_avg_reb
#    team_player2_avg_fg3a
#    team_player2_avg_fga
#    team_player2_avg_fgm
#    team_player2_avg_fta
#    team_player2_avg_reb
#    team_player2_games_in_average
#    team_player3_avg_fg3a
#    team_player3_avg_fga
#    team_player3_avg_fgm
#    team_player3_avg_fta
#    team_player3_avg_reb
#    team_player4_avg_fg3a
#    team_player4_avg_fga
#    team_player4_avg_fgm
#    team_player4_avg_fta
#    team_player4_avg_reb
#    team_player4_games_in_average
#    team_player5_avg_fg3a
#    team_player5_avg_fga
#    team_player5_avg_fgm
#    team_player5_avg_fta
#    team_player5_avg_reb
#    team_player6_avg_fg3a
#    team_player6_avg_fga
#    team_player6_avg_fgm
#    team_player6_avg_fta
#    team_player6_avg_reb
#    team_player7_avg_fg3a
#    team_player7_avg_fgm
#    team_player7_avg_fta
#    team_player7_avg_reb
#    team_player8_avg_fg3a
#    team_player8_avg_fgm
#    team_player8_avg_fta
#    team_player8_avg_reb
#    team_player9_avg_fg3a
#    team_player9_avg_fga
#    team_player9_avg_fgm
#    team_player9_avg_fta
#    team_player9_avg_reb
#
# ================================================================================
# PLAYER VS TEAM FEATURE IMPORTANCE
# ================================================================================
#
# 📊 BY ANOVA F-SCORE:
#                   mean          sum  count
# category
# diff_stats   23.955114   359.326705     15
# opp_stats    14.052662   182.684606     13
# team_stats   13.386154   174.019996     13
# team_player   9.743106  1568.640038    161
# opp_player    7.927746  1268.439285    160
#
# 📊 BY MUTUAL INFORMATION:
#                  mean       sum  count
# category
# team_player  0.007776  1.251966    161
# team_stats   0.006886  0.089514     13
# opp_player   0.006697  1.071569    160
# diff_stats   0.006549  0.098233     15
# opp_stats    0.005992  0.077891     13
# 🔥 HIGHEST CORRELATIONS WITH TARGET:
# team_player2_avg_plus_minus    0.218183
# team_player1_avg_plus_minus    0.214223
# team_player3_avg_plus_minus    0.197791
# opp_player1_avg_plus_minus     0.193431
# opp_player2_avg_plus_minus     0.176280
# team_player5_avg_plus_minus    0.175123
# team_player4_avg_plus_minus    0.174965
# diff_dreb                      0.172674
# diff_tov                       0.167644
# diff_pts                       0.154446
# opp_player3_avg_plus_minus     0.153531
# team_player7_avg_plus_minus    0.140038
# team_dreb                      0.138886
# opp_player8_avg_plus_minus     0.136251
# opp_player1_avg_min            0.135777
# Name: target_win, dtype: float64

# %%
print(f"Team1 win rate: {ml_df['target_win'].mean():.1%}")
# Out:
# Team1 win rate: 56.0%

# %%
with engine.connect() as conn:
    sample = pd.read_sql(
        text("""
        SELECT game_id, team_id, team_abbreviation, team_matchup 
        FROM team_game_stats 
        WHERE season_id = '22023'
        LIMIT 20
    """),
        conn,
    )
    print(sample)
# Out:
#        game_id     team_id team_abbreviation team_matchup
# 0   0022301192  1610612755               PHI  PHI vs. BKN
# 1   0022301197  1610612759               SAS  SAS vs. DET
# 2   0022301190  1610612752               NYK  NYK vs. CHI
# 3   0022301194  1610612756               PHX    PHX @ MIN
# 4   0022301199  1610612746               LAC  LAC vs. HOU
# 5   0022301186  1610612764               WAS    WAS @ BOS
# 6   0022301196  1610612760               OKC  OKC vs. DAL
# 7   0022301193  1610612743               DEN    DEN @ MEM
# 8   0022301194  1610612750               MIN  MIN vs. PHX
# 9   0022301186  1610612738               BOS  BOS vs. WAS
# 10  0022301190  1610612741               CHI    CHI @ NYK
# 11  0022301200  1610612758               SAC  SAC vs. POR
# 12  0022301195  1610612740               NOP  NOP vs. LAL
# 13  0022301188  1610612737               ATL    ATL @ IND
# 14  0022301200  1610612757               POR    POR @ SAC
# 15  0022301199  1610612745               HOU    HOU @ LAC
# 16  0022301189  1610612748               MIA  MIA vs. TOR
# 17  0022301191  1610612753               ORL  ORL vs. MIL
# 18  0022301198  1610612762               UTA    UTA @ GSW
# 19  0022301189  1610612761               TOR    TOR @ MIA

# %%
import json

# Let's say 'filtered_df' is your final dataframe from the analysis
final_features = [col for col in filtered_df.columns if col != "target_win"]

# Save to a JSON file
with open("selected_features.json", "w") as f:
    json.dump(final_features, f)

print(f"✅ Saved {len(final_features)} selected features to 'selected_features.json'")
# Out:
# ✅ Saved 362 selected features to 'selected_features.json'
