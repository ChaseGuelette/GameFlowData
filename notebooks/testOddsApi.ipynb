# %%
import os

from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("ODDS_API_KEY")

# %%
import requests

SPORT = "basketball_nba"  # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = "us"  # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = "h2h,spreads"  # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = "decimal"  # decimal | american

DATE_FORMAT = "iso"  # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# sports_response = requests.get(
#     'https://api.the-odds-api.com/v4/sports',
#     params={
#         'api_key': API_KEY
#     }
# )


# if sports_response.status_code != 200:
#     print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

# else:
#     print('List of in season sports:', sports_response.json())

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

odds_response = requests.get(
    f"https://api.the-odds-api.com/v4/sports/{SPORT}/odds",
    params={
        "api_key": API_KEY,
        "regions": REGIONS,
        "markets": MARKETS,
        "oddsFormat": ODDS_FORMAT,
        "dateFormat": DATE_FORMAT,
    },
)

if odds_response.status_code != 200:
    print(
        f"Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}"
    )

else:
    odds_json = odds_response.json()
    print("Number of events:", len(odds_json))
    print(json.dumps(odds_json, indent=4))

    # Check the usage quota
    print("Remaining requests", odds_response.headers["x-requests-remaining"])
    print("Used requests", odds_response.headers["x-requests-used"])
# Out:
# Number of events: 10
# [
#     {
#         "id": "a3c377edabf29f3f3c05c1cd03c2701c",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2026-01-10T00:10:00Z",
#         "home_team": "Boston Celtics",
#         "away_team": "Toronto Raptors",
#         "bookmakers": [
#             {
#                 "key": "fanduel",
#                 "title": "FanDuel",
#                 "last_update": "2026-01-09T15:53:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.29
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.75
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.91,
#                                 "point": -8.5
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.91,
#                                 "point": 8.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "fanatics",
#                 "title": "Fanatics",
#                 "last_update": "2026-01-09T15:51:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.29
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.6
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.91,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.91,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mybookieag",
#                 "title": "MyBookie.ag",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.29
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.65
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.91,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.91,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "draftkings",
#                 "title": "DraftKings",
#                 "last_update": "2026-01-09T15:54:29Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.32
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.98,
#                                 "point": -9.5
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.85,
#                                 "point": 9.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill_us",
#                 "title": "Caesars",
#                 "last_update": "2026-01-09T15:53:19Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.29
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.7
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.95,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.87,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "lowvig",
#                 "title": "LowVig.ag",
#                 "last_update": "2026-01-09T15:54:17Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.31
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.71
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.93,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.96,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betonlineag",
#                 "title": "BetOnline.ag",
#                 "last_update": "2026-01-09T15:53:26Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.3
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.67
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.89,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.93,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betrivers",
#                 "title": "BetRivers",
#                 "last_update": "2026-01-09T15:54:03Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.26
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.85
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.92,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.85,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betus",
#                 "title": "BetUS",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.3
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.7
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.91,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.91,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betmgm",
#                 "title": "BetMGM",
#                 "last_update": "2026-01-09T15:54:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.31
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.6
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.85,
#                                 "point": -8.5
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.98,
#                                 "point": 8.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "bovada",
#                 "title": "Bovada",
#                 "last_update": "2026-01-09T15:54:04Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.3
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 3.65
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Boston Celtics",
#                                 "price": 1.91,
#                                 "point": -9.0
#                             },
#                             {
#                                 "name": "Toronto Raptors",
#                                 "price": 1.91,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "fd952e8cdfea032fd925806405cfaec3",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2026-01-10T00:10:00Z",
#         "home_team": "Washington Wizards",
#         "away_team": "New Orleans Pelicans",
#         "bookmakers": [
#             {
#                 "key": "fanduel",
#                 "title": "FanDuel",
#                 "last_update": "2026-01-09T15:53:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.22
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.88,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.94,
#                                 "point": 2.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mybookieag",
#                 "title": "MyBookie.ag",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.64
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.27
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "fanatics",
#                 "title": "Fanatics",
#                 "last_update": "2026-01-09T15:51:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.2
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betrivers",
#                 "title": "BetRivers",
#                 "last_update": "2026-01-09T15:54:03Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.7
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.14
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.92,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.85,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "draftkings",
#                 "title": "DraftKings",
#                 "last_update": "2026-01-09T15:54:29Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.7
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.2
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.85,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.98,
#                                 "point": 2.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill_us",
#                 "title": "Caesars",
#                 "last_update": "2026-01-09T15:53:19Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.22
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "lowvig",
#                 "title": "LowVig.ag",
#                 "last_update": "2026-01-09T15:54:17Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.27
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.93,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.96,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betonlineag",
#                 "title": "BetOnline.ag",
#                 "last_update": "2026-01-09T15:53:26Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.25
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.89,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.93,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betus",
#                 "title": "BetUS",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.25
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betmgm",
#                 "title": "BetMGM",
#                 "last_update": "2026-01-09T15:54:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.69
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.18
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.87,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.95,
#                                 "point": 2.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "bovada",
#                 "title": "Bovada",
#                 "last_update": "2026-01-09T15:54:04Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.74
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 2.15
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "New Orleans Pelicans",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Washington Wizards",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "9d66f595028bcd5407209c1aebd94b47",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2026-01-10T00:10:00Z",
#         "home_team": "Orlando Magic",
#         "away_team": "Philadelphia 76ers",
#         "bookmakers": [
#             {
#                 "key": "fanduel",
#                 "title": "FanDuel",
#                 "last_update": "2026-01-09T15:53:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.36
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.93,
#                                 "point": 3.0
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.89,
#                                 "point": -3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "fanatics",
#                 "title": "Fanatics",
#                 "last_update": "2026-01-09T15:51:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.3
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mybookieag",
#                 "title": "MyBookie.ag",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.3
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.63
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "draftkings",
#                 "title": "DraftKings",
#                 "last_update": "2026-01-09T15:54:29Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.36
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill_us",
#                 "title": "Caesars",
#                 "last_update": "2026-01-09T15:53:19Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.4
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.61
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "lowvig",
#                 "title": "LowVig.ag",
#                 "last_update": "2026-01-09T15:54:17Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.41
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.94,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.94,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betonlineag",
#                 "title": "BetOnline.ag",
#                 "last_update": "2026-01-09T15:53:26Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.4
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betrivers",
#                 "title": "BetRivers",
#                 "last_update": "2026-01-09T15:54:03Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.23
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.65
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.89,
#                                 "point": 3.0
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.88,
#                                 "point": -3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betus",
#                 "title": "BetUS",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.38
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betmgm",
#                 "title": "BetMGM",
#                 "last_update": "2026-01-09T15:54:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.35
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.61
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "bovada",
#                 "title": "Bovada",
#                 "last_update": "2026-01-09T15:54:04Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 2.35
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.62
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Orlando Magic",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             },
#                             {
#                                 "name": "Philadelphia 76ers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "05bfb1a6d7e7db4c0e42dbbc1dc676c1",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2026-01-10T00:40:00Z",
#         "home_team": "Brooklyn Nets",
#         "away_team": "Los Angeles Clippers",
#         "bookmakers": [
#             {
#                 "key": "fanduel",
#                 "title": "FanDuel",
#                 "last_update": "2026-01-09T15:53:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Brooklyn Nets",
#                                 "price": 2.6
#                             },
#                             {
#                                 "name": "Los Angeles Clippers",
#                                 "price": 1.53
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Brooklyn Nets",
#                                 "price": 1.94,
#                                 "point": 4.5
# ...
#                                 "price": 1.38
#                             },
#                             {
#                                 "name": "Portland Trail Blazers",
#                                 "price": 3.15
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Houston Rockets",
#                                 "price": 1.87,
#                                 "point": -6.5
#                             },
#                             {
#                                 "name": "Portland Trail Blazers",
#                                 "price": 1.95,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "a9857db3ddf26169b1e7cccd8e789eb0",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2026-01-10T03:40:00Z",
#         "home_team": "Los Angeles Lakers",
#         "away_team": "Milwaukee Bucks",
#         "bookmakers": [
#             {
#                 "key": "fanduel",
#                 "title": "FanDuel",
#                 "last_update": "2026-01-09T15:53:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.63
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.34
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:52Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.91,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.91,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "fanatics",
#                 "title": "Fanatics",
#                 "last_update": "2026-01-09T15:51:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.62
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.3
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:51:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mybookieag",
#                 "title": "MyBookie.ag",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.61
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.32
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "draftkings",
#                 "title": "DraftKings",
#                 "last_update": "2026-01-09T15:54:29Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.62
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.36
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:29Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 2.0,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.83,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill_us",
#                 "title": "Caesars",
#                 "last_update": "2026-01-09T15:53:19Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.61
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.4
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:19Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.95,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.87,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "lowvig",
#                 "title": "LowVig.ag",
#                 "last_update": "2026-01-09T15:54:17Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.63
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.39
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:17Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.97,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.92,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betonlineag",
#                 "title": "BetOnline.ag",
#                 "last_update": "2026-01-09T15:53:26Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.63
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.38
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:26Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.93,
#                                 "point": -3.0
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.88,
#                                 "point": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betrivers",
#                 "title": "BetRivers",
#                 "last_update": "2026-01-09T15:54:03Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.63
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.28
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:03Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.92,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.85,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betmgm",
#                 "title": "BetMGM",
#                 "last_update": "2026-01-09T15:54:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.62
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.35
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "bovada",
#                 "title": "Bovada",
#                 "last_update": "2026-01-09T15:54:04Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.62
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.35
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:54:04Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.95,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.87,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betus",
#                 "title": "BetUS",
#                 "last_update": "2026-01-09T15:53:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.61
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 2.42
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2026-01-09T15:53:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Lakers",
#                                 "price": 1.91,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Milwaukee Bucks",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]
# Remaining requests 99996
# Used requests 4
