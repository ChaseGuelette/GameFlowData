# %%
#now we need to create a script for the players with no team ID

# %%
from sqlalchemy import create_engine, text 
import pandas as pd
import time
import random

from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster

teams = teams.get_teams()
print(teams)
big_df = pd.DataFrame()

for team in teams:
    roster = commonteamroster.CommonTeamRoster(team_id=team['id'])
    roster_df = roster.get_data_frames()[0]
    print(f"grabbing data for {team['full_name']}")
    
    big_df = pd.concat([big_df, roster_df])
    time.sleep(round(random.uniform(2, 3), 1))


engine = create_engine('postgresql://chase:yourpassword@localhost:5433/TeamData')

player_dict = {
    203471: "Dennis Schröder",
    20078: "P.J. Tucker",
    1627827: "Dorian Finney-Smith",
    1629003: "Shake Milton",
    1641998: "Trey Jemison III",
    1641803: "Tristen Newton",
    1626156: "D'Angelo Russell",
    1641736: "Reece Beekman",
    1641721: "Maxwell Lewis",
    202711: "Bojan Bogdanović",
    1628418: "Thomas Bryant",
    1630208: "Nick Richards",
    1631115: "Orlando Robinson",
    1629006: "Josh Okogie"
}

for player in player_dict:
    player_id = player
    
    player_stats = big_df[big_df['PLAYER_ID'] == player_id]
    print(player_stats)
    
    if not player_stats.empty:
        team_id = int(player_stats['TeamID'].iloc[0])
    else:
        print(f"No player found with ID {player_id}")    
    
    with engine.connect() as conn:
        with conn.begin():
            update_query = text("""
                UPDATE "all_players_misc_stats"
                SET "TEAM_ID" = :team_id
                WHERE "PLAYER_ID" = :player_id
            """)
            
            conn.execute(update_query, {"team_id" : team_id, "player_id" : player_id})
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Georgia', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}, {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}, {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}, {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}, {'id': 1610612742, 'full_name': 'Dallas Mavericks', 'abbreviation': 'DAL', 'nickname': 'Mavericks', 'city': 'Dallas', 'state': 'Texas', 'year_founded': 1980}, {'id': 1610612743, 'full_name': 'Denver Nuggets', 'abbreviation': 'DEN', 'nickname': 'Nuggets', 'city': 'Denver', 'state': 'Colorado', 'year_founded': 1976}, {'id': 1610612744, 'full_name': 'Golden State Warriors', 'abbreviation': 'GSW', 'nickname': 'Warriors', 'city': 'Golden State', 'state': 'California', 'year_founded': 1946}, {'id': 1610612745, 'full_name': 'Houston Rockets', 'abbreviation': 'HOU', 'nickname': 'Rockets', 'city': 'Houston', 'state': 'Texas', 'year_founded': 1967}, {'id': 1610612746, 'full_name': 'Los Angeles Clippers', 'abbreviation': 'LAC', 'nickname': 'Clippers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1970}, {'id': 1610612747, 'full_name': 'Los Angeles Lakers', 'abbreviation': 'LAL', 'nickname': 'Lakers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1948}, {'id': 1610612748, 'full_name': 'Miami Heat', 'abbreviation': 'MIA', 'nickname': 'Heat', 'city': 'Miami', 'state': 'Florida', 'year_founded': 1988}, {'id': 1610612749, 'full_name': 'Milwaukee Bucks', 'abbreviation': 'MIL', 'nickname': 'Bucks', 'city': 'Milwaukee', 'state': 'Wisconsin', 'year_founded': 1968}, {'id': 1610612750, 'full_name': 'Minnesota Timberwolves', 'abbreviation': 'MIN', 'nickname': 'Timberwolves', 'city': 'Minnesota', 'state': 'Minnesota', 'year_founded': 1989}, {'id': 1610612751, 'full_name': 'Brooklyn Nets', 'abbreviation': 'BKN', 'nickname': 'Nets', 'city': 'Brooklyn', 'state': 'New York', 'year_founded': 1976}, {'id': 1610612752, 'full_name': 'New York Knicks', 'abbreviation': 'NYK', 'nickname': 'Knicks', 'city': 'New York', 'state': 'New York', 'year_founded': 1946}, {'id': 1610612753, 'full_name': 'Orlando Magic', 'abbreviation': 'ORL', 'nickname': 'Magic', 'city': 'Orlando', 'state': 'Florida', 'year_founded': 1989}, {'id': 1610612754, 'full_name': 'Indiana Pacers', 'abbreviation': 'IND', 'nickname': 'Pacers', 'city': 'Indiana', 'state': 'Indiana', 'year_founded': 1976}, {'id': 1610612755, 'full_name': 'Philadelphia 76ers', 'abbreviation': 'PHI', 'nickname': '76ers', 'city': 'Philadelphia', 'state': 'Pennsylvania', 'year_founded': 1949}, {'id': 1610612756, 'full_name': 'Phoenix Suns', 'abbreviation': 'PHX', 'nickname': 'Suns', 'city': 'Phoenix', 'state': 'Arizona', 'year_founded': 1968}, {'id': 1610612757, 'full_name': 'Portland Trail Blazers', 'abbreviation': 'POR', 'nickname': 'Trail Blazers', 'city': 'Portland', 'state': 'Oregon', 'year_founded': 1970}, {'id': 1610612758, 'full_name': 'Sacramento Kings', 'abbreviation': 'SAC', 'nickname': 'Kings', 'city': 'Sacramento', 'state': 'California', 'year_founded': 1948}, {'id': 1610612759, 'full_name': 'San Antonio Spurs', 'abbreviation': 'SAS', 'nickname': 'Spurs', 'city': 'San Antonio', 'state': 'Texas', 'year_founded': 1976}, {'id': 1610612760, 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC', 'nickname': 'Thunder', 'city': 'Oklahoma City', 'state': 'Oklahoma', 'year_founded': 1967}, {'id': 1610612761, 'full_name': 'Toronto Raptors', 'abbreviation': 'TOR', 'nickname': 'Raptors',  ...
# grabbing data for Atlanta Hawks
# grabbing data for Boston Celtics
# grabbing data for Cleveland Cavaliers
# grabbing data for New Orleans Pelicans
# grabbing data for Chicago Bulls
# grabbing data for Dallas Mavericks
# grabbing data for Denver Nuggets
# grabbing data for Golden State Warriors
# grabbing data for Houston Rockets
# grabbing data for Los Angeles Clippers
# grabbing data for Los Angeles Lakers
# grabbing data for Miami Heat
# grabbing data for Milwaukee Bucks
# grabbing data for Minnesota Timberwolves
# grabbing data for Brooklyn Nets
# grabbing data for New York Knicks
# grabbing data for Orlando Magic
# grabbing data for Indiana Pacers
# grabbing data for Philadelphia 76ers
# grabbing data for Phoenix Suns
# grabbing data for Portland Trail Blazers
# grabbing data for Sacramento Kings
# grabbing data for San Antonio Spurs
# grabbing data for Oklahoma City Thunder
# grabbing data for Toronto Raptors
# grabbing data for Utah Jazz
# grabbing data for Memphis Grizzlies
# grabbing data for Washington Wizards
# grabbing data for Detroit Pistons
# grabbing data for Charlotte Hornets
#         TeamID SEASON LeagueID           PLAYER NICKNAME      PLAYER_SLUG NUM  \
# 17  1610612765   2024       00  Dennis Schröder   Dennis  dennis-schröder  71
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  PLAYER_ID  \
# 17        G    6-1    175  SEP 15, 1993  31.0  11  Braunschweig     203471
#
#                    HOW_ACQUIRED
# 17  Traded from GSW on 02/06/25
# Empty DataFrame
# Columns: [TeamID, SEASON, LeagueID, PLAYER, NICKNAME, PLAYER_SLUG, NUM, POSITION, HEIGHT, WEIGHT, BIRTH_DATE, AGE, EXP, SCHOOL, PLAYER_ID, HOW_ACQUIRED]
# Index: []
# No player found with ID 20078
#        TeamID SEASON LeagueID               PLAYER NICKNAME  \
# 9  1610612747   2024       00  Dorian Finney-Smith   Dorian
#
#            PLAYER_SLUG NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP  \
# 9  dorian-finney-smith  17        F    6-7    220  MAY 04, 1993  31.0   8
#
#     SCHOOL  PLAYER_ID                 HOW_ACQUIRED
# 9  Florida    1627827  Traded from BKN on 12/29/24
#         TeamID SEASON LeagueID        PLAYER NICKNAME   PLAYER_SLUG NUM  \
# 10  1610612747   2024       00  Shake Milton    Shake  shake-milton  20
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP              SCHOOL  \
# 10        G    6-5    205  SEP 26, 1996  28.0   6  Southern Methodist
#
#     PLAYER_ID                 HOW_ACQUIRED
# 10    1629003  Traded from BKN on 12/29/24
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 15  1610612747   2024       00  Trey Jemison III     Trey  trey-jemison-iii
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP              SCHOOL  \
# 15  55        C   6-10    260  NOV 28, 1999  25.0   1  Alabama-Birmingham
#
#     PLAYER_ID        HOW_ACQUIRED
# 15    1641998  Signed on 01/15/25
#         TeamID SEASON LeagueID          PLAYER NICKNAME     PLAYER_SLUG NUM  \
# 10  1610612750   2024       00  Tristen Newton  Tristen  tristen-newton  13
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP       SCHOOL  PLAYER_ID  \
# 10        G    6-5    190  APR 26, 2001  23.0   R  Connecticut    1641803
#
#    HOW_ACQUIRED
# 10         None
#        TeamID SEASON LeagueID            PLAYER  NICKNAME      PLAYER_SLUG  \
# 1  1610612751   2024       00  D'Angelo Russell  D'Angelo  dangelo-russell
#
#   NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 1   1        G    6-3    193  FEB 23, 1996  28.0   9  Ohio State    1626156
#
#                   HOW_ACQUIRED
# 1  Traded from LAL on 12/29/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 3  1610612751   2024       00  Reece Beekman    Reece  reece-beekman   4
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP    SCHOOL  PLAYER_ID  \
# 3        G    6-3    190  OCT 08, 2001  23.0   R  Virginia    1641736
#
#   HOW_ACQUIRED
# 3         None
#         TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 13  1610612751   2024       00  Maxwell Lewis  Maxwell  maxwell-lewis  27
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 13        F    6-7    215  JUL 27, 2002  22.0   1  Pepperdine    1641721
#
#                    HOW_ACQUIRED
# 13  Traded from LAL on 12/29/24
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 15  1610612751   2024       00  Bojan Bogdanović    Bojan  bojan-bogdanović
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 15  44        F    6-7    226  APR 18, 1989  35.0  10  Fenerbahce     202711
#
#                    HOW_ACQUIRED
# 15  Traded from NYK on 07/06/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 4  1610612754   2024       00  Thomas Bryant   Thomas  thomas-bryant   3
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP   SCHOOL  PLAYER_ID  \
# 4      C-F   6-10    248  JUL 31, 1997  27.0   7  Indiana    1628418
#
#                   HOW_ACQUIRED
# 4  Traded from MIA on 12/15/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 3  1610612756   2024       00  Nick Richards     Nick  nick-richards   2
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP    SCHOOL  PLAYER_ID  \
# 3        C    7-0    245  NOV 29, 1997  27.0   4  Kentucky    1630208
#
#                   HOW_ACQUIRED
# 3  Traded from CHA on 01/15/25
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 11  1610612761   2024       00  Orlando Robinson  Orlando  orlando-robinson
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  \
# 11  21        C   6-10    235  JUL 10, 2000  24.0   2  Fresno State
#
#     PLAYER_ID        HOW_ACQUIRED
# 11    1631115  Signed on 01/18/25
#        TeamID SEASON LeagueID       PLAYER NICKNAME  PLAYER_SLUG NUM POSITION  \
# 8  1610612766   2024       00  Josh Okogie     Josh  josh-okogie  12        G
#
#   HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  PLAYER_ID  \
# 8    6-4    213  SEP 01, 1998  26.0   6  Georgia Tech    1629006
#
#                   HOW_ACQUIRED
# 8  Traded from PHX on 01/15/25

# %%
roster = commonteamroster.CommonTeamRoster(team_id='1610612744')
roster_df = roster.get_data_frames()[0]
roster_df
# Out:
#         TeamID SEASON LeagueID                PLAYER  NICKNAME  \
# 0   1610612744   2024       00        Gary Payton II      Gary
# 1   1610612744   2024       00      Jonathan Kuminga  Jonathan
# 2   1610612744   2024       00         Kyle Anderson      Kyle
# 3   1610612744   2024       00    Brandin Podziemski   Brandin
# 4   1610612744   2024       00           Moses Moody     Moses
# 5   1610612744   2024       00          Kevon Looney     Kevon
# 6   1610612744   2024       00           Buddy Hield     Buddy
# 7   1610612744   2024       00            Gui Santos       Gui
# 8   1610612744   2024       00          Quinten Post   Quinten
# 9   1610612744   2024       00        Andrew Wiggins    Andrew
# 10  1610612744   2024       00        Draymond Green  Draymond
# 11  1610612744   2024       00         Stephen Curry   Stephen
# 12  1610612744   2024       00  Trayce Jackson-Davis    Trayce
# 13  1610612744   2024       00      Lindy Waters III     Lindy
# 14  1610612744   2024       00          Jackson Rowe   Jackson
# 15  1610612744   2024       00           Pat Spencer       Pat
# 16  1610612744   2024       00       Dennis Schröder    Dennis
#
#              PLAYER_SLUG NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP  \
# 0         gary-payton-ii   0        G    6-2    195  DEC 01, 1992  32.0   8
# 1       jonathan-kuminga  00        F    6-7    225  OCT 06, 2002  22.0   3
# 2          kyle-anderson   1      F-G    6-9    230  SEP 20, 1993  31.0  10
# 3     brandin-podziemski   2        G    6-4    205  FEB 25, 2003  21.0   1
# 4            moses-moody   4        G    6-5    211  MAY 31, 2002  22.0   3
# 5           kevon-looney   5        F    6-9    222  FEB 06, 1996  28.0   9
# 6            buddy-hield   7        G    6-4    220  DEC 17, 1992  32.0   8
# 7             gui-santos  15        F    6-6    185  JUN 22, 2002  22.0   1
# 8           quinten-post  21        C    7-0    238  MAR 21, 2000  24.0   R
# 9         andrew-wiggins  22        F    6-7    197  FEB 23, 1995  29.0  10
# 10        draymond-green  23        F    6-6    230  MAR 04, 1990  34.0  12
# 11         stephen-curry  30        G    6-2    185  MAR 14, 1988  36.0  15
# 12  trayce-jackson-davis  32        F    6-9    245  FEB 22, 2000  24.0   1
# 13      lindy-waters-iii  43        F    6-6    210  JUL 28, 1997  27.0   3
# 14          jackson-rowe  44        F    6-7    210  JAN 04, 1997  28.0   R
# 15           pat-spencer  61        G    6-3    205  JUL 04, 1996  28.0   1
# 16       dennis-schröder  71        G    6-1    175  SEP 15, 1993  31.0  11
#
#                         SCHOOL  PLAYER_ID  \
# 0                 Oregon State    1627780
# 1          NBA G League Ignite    1630228
# 2                         UCLA     203937
# 3                  Santa Clara    1641764
# 4                     Arkansas    1630541
# 5                         UCLA    1626172
# 6                     Oklahoma    1627741
# 7                        Minas    1630611
# 8               Boston College    1642366
# 9                       Kansas     203952
# 10              Michigan State     203110
# 11                    Davidson     201939
# 12                     Indiana    1631218
# 13              Oklahoma State    1630322
# 14  California State-Fullerton    1642050
# 15                Northwestern    1630311
# 16                Braunschweig     203471
#
#                                 HOW_ACQUIRED
# 0                Traded from POR on 02/09/23
# 1                      #7 Pick in 2021 Draft
# 2                Traded from MIN on 07/06/24
# 3                     #19 Pick in 2023 Draft
# 4                     #14 Pick in 2021 Draft
# 5                     #30 Pick in 2015 Draft
# 6                Traded from PHI on 07/06/24
# 7                     #55 Pick in 2022 Draft
# 8   Draft Rights Traded from POR on 07/06/24
# 9                Traded from MIN on 02/06/20
# 10                    #35 Pick in 2012 Draft
# 11                     #7 Pick in 2009 Draft
# 12  Draft Rights Traded from WAS on 06/23/23
# 13               Traded from OKC on 06/27/24
# 14                        Signed on 07/19/24
# 15                        Signed on 07/23/22
# 16               Traded from BKN on 12/15/24

# %%
from sqlalchemy import create_engine, text 
import pandas as pd
import time
import random

from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster

teams = teams.get_teams()
print(teams)
big_df = pd.DataFrame()

for team in teams:
    roster = commonteamroster.CommonTeamRoster(team_id=team['id'])
    roster_df = roster.get_data_frames()[0]
    print(f"grabbing data for {team['full_name']}")
    
    big_df = pd.concat([big_df, roster_df])
    time.sleep(round(random.uniform(2, 3), 1))
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Georgia', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}, {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}, {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}, {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}, {'id': 1610612742, 'full_name': 'Dallas Mavericks', 'abbreviation': 'DAL', 'nickname': 'Mavericks', 'city': 'Dallas', 'state': 'Texas', 'year_founded': 1980}, {'id': 1610612743, 'full_name': 'Denver Nuggets', 'abbreviation': 'DEN', 'nickname': 'Nuggets', 'city': 'Denver', 'state': 'Colorado', 'year_founded': 1976}, {'id': 1610612744, 'full_name': 'Golden State Warriors', 'abbreviation': 'GSW', 'nickname': 'Warriors', 'city': 'Golden State', 'state': 'California', 'year_founded': 1946}, {'id': 1610612745, 'full_name': 'Houston Rockets', 'abbreviation': 'HOU', 'nickname': 'Rockets', 'city': 'Houston', 'state': 'Texas', 'year_founded': 1967}, {'id': 1610612746, 'full_name': 'Los Angeles Clippers', 'abbreviation': 'LAC', 'nickname': 'Clippers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1970}, {'id': 1610612747, 'full_name': 'Los Angeles Lakers', 'abbreviation': 'LAL', 'nickname': 'Lakers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1948}, {'id': 1610612748, 'full_name': 'Miami Heat', 'abbreviation': 'MIA', 'nickname': 'Heat', 'city': 'Miami', 'state': 'Florida', 'year_founded': 1988}, {'id': 1610612749, 'full_name': 'Milwaukee Bucks', 'abbreviation': 'MIL', 'nickname': 'Bucks', 'city': 'Milwaukee', 'state': 'Wisconsin', 'year_founded': 1968}, {'id': 1610612750, 'full_name': 'Minnesota Timberwolves', 'abbreviation': 'MIN', 'nickname': 'Timberwolves', 'city': 'Minnesota', 'state': 'Minnesota', 'year_founded': 1989}, {'id': 1610612751, 'full_name': 'Brooklyn Nets', 'abbreviation': 'BKN', 'nickname': 'Nets', 'city': 'Brooklyn', 'state': 'New York', 'year_founded': 1976}, {'id': 1610612752, 'full_name': 'New York Knicks', 'abbreviation': 'NYK', 'nickname': 'Knicks', 'city': 'New York', 'state': 'New York', 'year_founded': 1946}, {'id': 1610612753, 'full_name': 'Orlando Magic', 'abbreviation': 'ORL', 'nickname': 'Magic', 'city': 'Orlando', 'state': 'Florida', 'year_founded': 1989}, {'id': 1610612754, 'full_name': 'Indiana Pacers', 'abbreviation': 'IND', 'nickname': 'Pacers', 'city': 'Indiana', 'state': 'Indiana', 'year_founded': 1976}, {'id': 1610612755, 'full_name': 'Philadelphia 76ers', 'abbreviation': 'PHI', 'nickname': '76ers', 'city': 'Philadelphia', 'state': 'Pennsylvania', 'year_founded': 1949}, {'id': 1610612756, 'full_name': 'Phoenix Suns', 'abbreviation': 'PHX', 'nickname': 'Suns', 'city': 'Phoenix', 'state': 'Arizona', 'year_founded': 1968}, {'id': 1610612757, 'full_name': 'Portland Trail Blazers', 'abbreviation': 'POR', 'nickname': 'Trail Blazers', 'city': 'Portland', 'state': 'Oregon', 'year_founded': 1970}, {'id': 1610612758, 'full_name': 'Sacramento Kings', 'abbreviation': 'SAC', 'nickname': 'Kings', 'city': 'Sacramento', 'state': 'California', 'year_founded': 1948}, {'id': 1610612759, 'full_name': 'San Antonio Spurs', 'abbreviation': 'SAS', 'nickname': 'Spurs', 'city': 'San Antonio', 'state': 'Texas', 'year_founded': 1976}, {'id': 1610612760, 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC', 'nickname': 'Thunder', 'city': 'Oklahoma City', 'state': 'Oklahoma', 'year_founded': 1967}, {'id': 1610612761, 'full_name': 'Toronto Raptors', 'abbreviation': 'TOR', 'nickname': 'Raptors',  ...
# grabbing data for Atlanta Hawks
# grabbing data for Boston Celtics
# grabbing data for Cleveland Cavaliers
# grabbing data for New Orleans Pelicans
# grabbing data for Chicago Bulls
# grabbing data for Dallas Mavericks
# grabbing data for Denver Nuggets
# grabbing data for Golden State Warriors
# grabbing data for Houston Rockets
# grabbing data for Los Angeles Clippers
# grabbing data for Los Angeles Lakers
# grabbing data for Miami Heat
# grabbing data for Milwaukee Bucks
# grabbing data for Minnesota Timberwolves
# grabbing data for Brooklyn Nets
# grabbing data for New York Knicks
# grabbing data for Orlando Magic
# grabbing data for Indiana Pacers
# grabbing data for Philadelphia 76ers
# grabbing data for Phoenix Suns
# grabbing data for Portland Trail Blazers
# grabbing data for Sacramento Kings
# grabbing data for San Antonio Spurs
# grabbing data for Oklahoma City Thunder
# grabbing data for Toronto Raptors
# grabbing data for Utah Jazz
# grabbing data for Memphis Grizzlies
# grabbing data for Washington Wizards
# grabbing data for Detroit Pistons
# grabbing data for Charlotte Hornets

# %%
big_df
# Out:
#         TeamID SEASON LeagueID          PLAYER NICKNAME     PLAYER_SLUG NUM  \
# 0   1610612737   2024       00   Jalen Johnson    Jalen   jalen-johnson   1
# 1   1610612737   2024       00  Keaton Wallace   Keaton  keaton-wallace   2
# 2   1610612737   2024       00     Kobe Bufkin     Kobe     kobe-bufkin   4
# 3   1610612737   2024       00   Dyson Daniels    Dyson   dyson-daniels   5
# 4   1610612737   2024       00     David Roddy    David     david-roddy   8
# ..         ...    ...      ...             ...      ...             ...  ..
# 13  1610612766   2024       00  Brandon Miller  Brandon  brandon-miller  24
# 14  1610612766   2024       00      KJ Simpson       KJ      kj-simpson  25
# 15  1610612766   2024       00      Seth Curry     Seth      seth-curry  30
# 16  1610612766   2024       00  Tidjane Salaün  Tidjane  tidjane-salaün  31
# 17  1610612766   2024       00      Taj Gibson      Taj      taj-gibson  67
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP               SCHOOL  \
# 0         F    6-8    219  DEC 18, 2001  23.0   3                 Duke
# 1         G    6-3    185  FEB 26, 1999  25.0   R    Texas-San Antonio
# 2         G    6-4    195  SEP 21, 2003  21.0   1             Michigan
# 3         G    6-7    199  MAR 17, 2003  21.0   2  NBA G League Ignite
# 4         F    6-4    255  MAR 27, 2001  23.0   2       Colorado State
# ..      ...    ...    ...           ...   ...  ..                  ...
# 13        F    6-7    200  NOV 22, 2002  22.0   1              Alabama
# 14        G    6-0    189  AUG 08, 2002  22.0   R             Colorado
# 15        G    6-1    185  AUG 23, 1990  34.0  10                 Duke
# 16        F    6-8    207  AUG 10, 2005  19.0   R               Cholet
# 17        F    6-9    232  JUN 24, 1985  39.0  15  Southern California
#
#     PLAYER_ID                 HOW_ACQUIRED
# 0     1630552       #20 Pick in 2021 Draft
# 1     1630811           Signed on 09/29/23
# 2     1641723       #15 Pick in 2023 Draft
# 3     1630700  Traded from NOP on 07/06/24
# 4     1631223  Traded from PHX on 07/29/24
# ..        ...                          ...
# 13    1641706        #2 Pick in 2023 Draft
# 14    1642354       #42 Pick in 2024 Draft
# 15     203552  Traded from DAL on 02/08/24
# 16    1642275        #6 Pick in 2024 Draft
# 17     201959           Signed on 07/13/24
#
# [526 rows x 16 columns]

# %%
player_stats = big_df[big_df['PLAYER_ID'] == 203471]
# player_stats - big_df.iloc[big_df.iloc[:, 1] == '203471']
player_stats
# Out:
#         TeamID SEASON LeagueID           PLAYER NICKNAME      PLAYER_SLUG NUM  \
# 16  1610612744   2024       00  Dennis Schröder   Dennis  dennis-schröder  71
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  PLAYER_ID  \
# 16        G    6-1    175  SEP 15, 1993  31.0  11  Braunschweig     203471
#
#                    HOW_ACQUIRED
# 16  Traded from BKN on 12/15/24

# %%
from sqlalchemy import create_engine, text 
import pandas as pd

engine = create_engine('postgresql://chase:yourpassword@localhost:5433/TeamData')

player_dict = {
    203471: "Dennis Schröder",
    20078: "P.J. Tucker",
    1627827: "Dorian Finney-Smith",
    1629003: "Shake Milton",
    1641998: "Trey Jemison III",
    1641803: "Tristen Newton",
    1626156: "D'Angelo Russell",
    1641736: "Reece Beekman",
    1641721: "Maxwell Lewis",
    202711: "Bojan Bogdanović",
    1628418: "Thomas Bryant",
    1630208: "Nick Richards",
    1631115: "Orlando Robinson",
    1629006: "Josh Okogie"
}

for player in player_dict:
    player_id = player
    
    player_stats = big_df[big_df['PLAYER_ID'] == player_id]
    print(player_stats)
    
    if not player_stats.empty:
        team_id = int(player_stats['TeamID'].iloc[0])
    else:
        print(f"No player found with ID {player_id}")    
    
    with engine.connect() as conn:
        with conn.begin():
            update_query = text("""
                UPDATE "all_players_misc_stats"
                SET "TEAM_ID" = :team_id
                WHERE "PLAYER_ID" = :player_id
            """)
            
            conn.execute(update_query, {"team_id" : team_id, "player_id" : player_id})
# Out:
#         TeamID SEASON LeagueID           PLAYER NICKNAME      PLAYER_SLUG NUM  \
# 16  1610612744   2024       00  Dennis Schröder   Dennis  dennis-schröder  71
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  PLAYER_ID  \
# 16        G    6-1    175  SEP 15, 1993  31.0  11  Braunschweig     203471
#
#                    HOW_ACQUIRED
# 16  Traded from BKN on 12/15/24
# Empty DataFrame
# Columns: [TeamID, SEASON, LeagueID, PLAYER, NICKNAME, PLAYER_SLUG, NUM, POSITION, HEIGHT, WEIGHT, BIRTH_DATE, AGE, EXP, SCHOOL, PLAYER_ID, HOW_ACQUIRED]
# Index: []
# No player found with ID 20078
#        TeamID SEASON LeagueID               PLAYER NICKNAME  \
# 8  1610612747   2024       00  Dorian Finney-Smith   Dorian
#
#            PLAYER_SLUG NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP  \
# 8  dorian-finney-smith  17        F    6-7    220  MAY 04, 1993  31.0   8
#
#     SCHOOL  PLAYER_ID                 HOW_ACQUIRED
# 8  Florida    1627827  Traded from BKN on 12/29/24
#        TeamID SEASON LeagueID        PLAYER NICKNAME   PLAYER_SLUG NUM  \
# 9  1610612747   2024       00  Shake Milton    Shake  shake-milton  20
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP              SCHOOL  \
# 9        G    6-5    205  SEP 26, 1996  28.0   6  Southern Methodist
#
#    PLAYER_ID                 HOW_ACQUIRED
# 9    1629003  Traded from BKN on 12/29/24
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 14  1610612747   2024       00  Trey Jemison III     Trey  trey-jemison-iii
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP              SCHOOL  \
# 14  55        C   6-10    260  NOV 28, 1999  25.0   1  Alabama-Birmingham
#
#     PLAYER_ID        HOW_ACQUIRED
# 14    1641998  Signed on 01/15/25
#         TeamID SEASON LeagueID          PLAYER NICKNAME     PLAYER_SLUG NUM  \
# 10  1610612750   2024       00  Tristen Newton  Tristen  tristen-newton  13
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP       SCHOOL  PLAYER_ID  \
# 10        G    6-5    190  APR 26, 2001  23.0   R  Connecticut    1641803
#
#    HOW_ACQUIRED
# 10         None
#        TeamID SEASON LeagueID            PLAYER  NICKNAME      PLAYER_SLUG  \
# 1  1610612751   2024       00  D'Angelo Russell  D'Angelo  dangelo-russell
#
#   NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 1   1        G    6-3    193  FEB 23, 1996  28.0   9  Ohio State    1626156
#
#                   HOW_ACQUIRED
# 1  Traded from LAL on 12/29/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 3  1610612751   2024       00  Reece Beekman    Reece  reece-beekman   4
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP    SCHOOL  PLAYER_ID  \
# 3        G    6-3    190  OCT 08, 2001  23.0   R  Virginia    1641736
#
#   HOW_ACQUIRED
# 3         None
#         TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 14  1610612751   2024       00  Maxwell Lewis  Maxwell  maxwell-lewis  27
#
#    POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 14        F    6-7    215  JUL 27, 2002  22.0   1  Pepperdine    1641721
#
#                    HOW_ACQUIRED
# 14  Traded from LAL on 12/29/24
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 16  1610612751   2024       00  Bojan Bogdanović    Bojan  bojan-bogdanović
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP      SCHOOL  PLAYER_ID  \
# 16  44        F    6-7    226  APR 18, 1989  35.0  10  Fenerbahce     202711
#
#                    HOW_ACQUIRED
# 16  Traded from NYK on 07/06/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 4  1610612754   2024       00  Thomas Bryant   Thomas  thomas-bryant   3
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP   SCHOOL  PLAYER_ID  \
# 4      C-F   6-10    248  JUL 31, 1997  27.0   7  Indiana    1628418
#
#                   HOW_ACQUIRED
# 4  Traded from MIA on 12/15/24
#        TeamID SEASON LeagueID         PLAYER NICKNAME    PLAYER_SLUG NUM  \
# 3  1610612756   2024       00  Nick Richards     Nick  nick-richards   2
#
#   POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP    SCHOOL  PLAYER_ID  \
# 3        C    7-0    245  NOV 29, 1997  27.0   4  Kentucky    1630208
#
#                   HOW_ACQUIRED
# 3  Traded from CHA on 01/15/25
#         TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 17  1610612761   2024       00  Orlando Robinson  Orlando  orlando-robinson
#
#    NUM POSITION HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  \
# 17  77        C   6-10    235  JUL 10, 2000  24.0   2  Fresno State
#
#     PLAYER_ID        HOW_ACQUIRED
# 17    1631115  Signed on 01/18/25
#        TeamID SEASON LeagueID       PLAYER NICKNAME  PLAYER_SLUG NUM POSITION  \
# 8  1610612766   2024       00  Josh Okogie     Josh  josh-okogie  12        G
#
#   HEIGHT WEIGHT    BIRTH_DATE   AGE EXP        SCHOOL  PLAYER_ID  \
# 8    6-4    213  SEP 01, 1998  26.0   6  Georgia Tech    1629006
#
#                   HOW_ACQUIRED
# 8  Traded from PHX on 01/15/25

# %%
player_dict = {
    203471: "Dennis Schröder",
    20078: "P.J. Tucker",
    1627827: "Dorian Finney-Smith",
    1629003: "Shake Milton",
    1641998: "Trey Jemison III",
    1641803: "Tristen Newton",
    1626156: "D'Angelo Russell",
    1641736: "Reece Beekman",
    1641721: "Maxwell Lewis",
    202711: "Bojan Bogdanović",
    1628418: "Thomas Bryant",
    1630208: "Nick Richards",
    1631115: "Orlando Robinson",
    1629006: "Josh Okogie"
}

for player in player_dict:
    # player_id = player[0]
    print(player)
# Out:
# 203471
# 20078
# 1627827
# 1629003
# 1641998
# 1641803
# 1626156
# 1641736
# 1641721
# 202711
# 1628418
# 1630208
# 1631115
# 1629006

# %%
from sqlalchemy import create_engine, text 
import pandas as pd

from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster

teams = teams.get_teams()
print(teams)
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Georgia', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}, {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}, {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}, {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}, {'id': 1610612742, 'full_name': 'Dallas Mavericks', 'abbreviation': 'DAL', 'nickname': 'Mavericks', 'city': 'Dallas', 'state': 'Texas', 'year_founded': 1980}, {'id': 1610612743, 'full_name': 'Denver Nuggets', 'abbreviation': 'DEN', 'nickname': 'Nuggets', 'city': 'Denver', 'state': 'Colorado', 'year_founded': 1976}, {'id': 1610612744, 'full_name': 'Golden State Warriors', 'abbreviation': 'GSW', 'nickname': 'Warriors', 'city': 'Golden State', 'state': 'California', 'year_founded': 1946}, {'id': 1610612745, 'full_name': 'Houston Rockets', 'abbreviation': 'HOU', 'nickname': 'Rockets', 'city': 'Houston', 'state': 'Texas', 'year_founded': 1967}, {'id': 1610612746, 'full_name': 'Los Angeles Clippers', 'abbreviation': 'LAC', 'nickname': 'Clippers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1970}, {'id': 1610612747, 'full_name': 'Los Angeles Lakers', 'abbreviation': 'LAL', 'nickname': 'Lakers', 'city': 'Los Angeles', 'state': 'California', 'year_founded': 1948}, {'id': 1610612748, 'full_name': 'Miami Heat', 'abbreviation': 'MIA', 'nickname': 'Heat', 'city': 'Miami', 'state': 'Florida', 'year_founded': 1988}, {'id': 1610612749, 'full_name': 'Milwaukee Bucks', 'abbreviation': 'MIL', 'nickname': 'Bucks', 'city': 'Milwaukee', 'state': 'Wisconsin', 'year_founded': 1968}, {'id': 1610612750, 'full_name': 'Minnesota Timberwolves', 'abbreviation': 'MIN', 'nickname': 'Timberwolves', 'city': 'Minnesota', 'state': 'Minnesota', 'year_founded': 1989}, {'id': 1610612751, 'full_name': 'Brooklyn Nets', 'abbreviation': 'BKN', 'nickname': 'Nets', 'city': 'Brooklyn', 'state': 'New York', 'year_founded': 1976}, {'id': 1610612752, 'full_name': 'New York Knicks', 'abbreviation': 'NYK', 'nickname': 'Knicks', 'city': 'New York', 'state': 'New York', 'year_founded': 1946}, {'id': 1610612753, 'full_name': 'Orlando Magic', 'abbreviation': 'ORL', 'nickname': 'Magic', 'city': 'Orlando', 'state': 'Florida', 'year_founded': 1989}, {'id': 1610612754, 'full_name': 'Indiana Pacers', 'abbreviation': 'IND', 'nickname': 'Pacers', 'city': 'Indiana', 'state': 'Indiana', 'year_founded': 1976}, {'id': 1610612755, 'full_name': 'Philadelphia 76ers', 'abbreviation': 'PHI', 'nickname': '76ers', 'city': 'Philadelphia', 'state': 'Pennsylvania', 'year_founded': 1949}, {'id': 1610612756, 'full_name': 'Phoenix Suns', 'abbreviation': 'PHX', 'nickname': 'Suns', 'city': 'Phoenix', 'state': 'Arizona', 'year_founded': 1968}, {'id': 1610612757, 'full_name': 'Portland Trail Blazers', 'abbreviation': 'POR', 'nickname': 'Trail Blazers', 'city': 'Portland', 'state': 'Oregon', 'year_founded': 1970}, {'id': 1610612758, 'full_name': 'Sacramento Kings', 'abbreviation': 'SAC', 'nickname': 'Kings', 'city': 'Sacramento', 'state': 'California', 'year_founded': 1948}, {'id': 1610612759, 'full_name': 'San Antonio Spurs', 'abbreviation': 'SAS', 'nickname': 'Spurs', 'city': 'San Antonio', 'state': 'Texas', 'year_founded': 1976}, {'id': 1610612760, 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC', 'nickname': 'Thunder', 'city': 'Oklahoma City', 'state': 'Oklahoma', 'year_founded': 1967}, {'id': 1610612761, 'full_name': 'Toronto Raptors', 'abbreviation': 'TOR', 'nickname': 'Raptors',  ...

# %%
big_df = pd.DataFrame()

for team in teams:
    roster = commonteamroster.CommonTeamRoster(team_id=team['id'])
    roster_df = roster.get_data_frames()[0]
    pd.concat([big_df, roster_df])

roster_df
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[27], line 4
#       1 big_df = pd.DataFrame()
#       3 for team in teams:
# ----> 4     roster = commonteamroster.CommonTeamRoster(team_id=team['id'])
#       5     roster_df = roster.get_data_frames()[0]
#       6     pd.concat([big_df, roster_df])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nba_api\stats\endpoints\commonteamroster.py:64, in CommonTeamRoster.__init__(self, team_id, season, league_id_nullable, proxy, headers, timeout, get_request)
#      58 self.parameters = {
#      59     "TeamID": team_id,
#      60     "Season": season,
#      61     "LeagueID": league_id_nullable,
#      62 }
#      63 if get_request:
# ---> 64     self.get_request()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nba_api\stats\endpoints\commonteamroster.py:67, in CommonTeamRoster.get_request(self)
#      66 def get_request(self):
# ---> 67     self.nba_response = NBAStatsHTTP().send_api_request(
#      68         endpoint=self.endpoint,
#      69         parameters=self.parameters,
#      70         proxy=self.proxy,
#      71         headers=self.headers,
#      72         timeout=self.timeout,
#      73     )
#      74     self.load_response()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nba_api\library\http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
roster = commonteamroster.CommonTeamRoster(team_id=team['id'])
roster_df = roster.get_data_frames()[0]
