# %% [markdown]
# # NBA Advanced Stats Scraper
#
# Scrapes BoxScoreAdvancedV3 data for all games in the database.
#
# **Features:**
# - Resumable: Tracks progress in `scrape_advanced_stats_progress` table
# - Crash-safe: Commits every 50 games
# - Rate-limited: Random delays + long pauses to avoid API bans
# - DNP handling: Flags players who didn't play
#
# **Before running:**
# 1. Execute `advanced_stats_schema.sql` in Supabase to create tables
# 2. Ensure `.env` file has `DATABASE_URL`

# %%
# =============================================================================
# Imports and Setup
# =============================================================================

from requests.exceptions import ReadTimeout, ConnectionError
from sqlalchemy import create_engine, text, inspect
from dotenv import load_dotenv
from datetime import datetime
import pandas as pd
import numpy as np
import random
import time
import json
import re
import os

from nba_api.stats.endpoints import boxscoreadvancedv3

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print("Imports complete")
# Out:
# Imports complete

# %%
# =============================================================================
# Configuration
# =============================================================================

# Scraper settings
BATCH_SIZE = 50                    # Commit to DB every N games
SHORT_DELAY_MIN = 1.0              # Min seconds between API calls
SHORT_DELAY_MAX = 2.5              # Max seconds between API calls  
LONG_PAUSE_EVERY = 100             # Long pause every N games
LONG_PAUSE_MIN = 60                # Min seconds for long pause
LONG_PAUSE_MAX = 100               # Max seconds for long pause
ERROR_RETRY_DELAY = 180            # Seconds to wait after error
MAX_RETRIES = 3                    # Max retries per game before skipping

# Database connection
load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL")

if not DATABASE_URL:
    raise ValueError("DATABASE_URL not found in environment. Check your .env file.")

engine = create_engine(DATABASE_URL)
print(f"Connected to database")

# Test connection
with engine.connect() as conn:
    result = conn.execute(text("SELECT 1"))
    print("Database connection verified ✓")
# Out:
# Connected to database
# Database connection verified ✓

# %%
# =============================================================================
# Helper Functions
# =============================================================================

def camel_to_snake(name: str) -> str:
    """
    Convert camelCase to snake_case.
    e.g., 'offensiveRating' -> 'offensive_rating'
          'PIE' -> 'pie'
    """
    # Handle acronyms like PIE
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()


def parse_minutes(minutes_str) -> float:
    """
    Parse minutes from various formats to float.
    
    Handles:
    - 'MM:SS' format (e.g., '28:17' -> 28.283)
    - 'PT28M17.00S' ISO format
    - Already numeric values
    - None/empty/NaN -> 0.0
    """
    if pd.isna(minutes_str) or minutes_str == '' or minutes_str is None:
        return 0.0
    
    # Already numeric
    if isinstance(minutes_str, (int, float)):
        return float(minutes_str)
    
    minutes_str = str(minutes_str)
    
    # MM:SS format (BoxScoreAdvancedV3)
    if ':' in minutes_str and 'PT' not in minutes_str:
        try:
            parts = minutes_str.split(':')
            mins = int(parts[0])
            secs = int(parts[1]) if len(parts) > 1 else 0
            return round(mins + secs / 60, 3)
        except (ValueError, IndexError):
            return 0.0
    
    # ISO 8601 format (PT28M17.00S)
    if 'PT' in minutes_str:
        try:
            match = re.match(r'PT(\d+)M([\d.]+)S', minutes_str)
            if match:
                mins = int(match.group(1))
                secs = float(match.group(2))
                return round(mins + secs / 60, 3)
        except (ValueError, AttributeError):
            return 0.0
    
    return 0.0


def determine_dnp(row: pd.Series) -> bool:
    """
    Determine if a player did not play.
    
    DNP if:
    - 'comment' field contains text (usually DNP reason)
    - minutes is 0 or null
    """
    comment = row.get('comment', '')
    minutes = row.get('minutes', 0)
    
    # Has a comment (DNP reason)
    if pd.notna(comment) and str(comment).strip() != '':
        return True
    
    # Zero or null minutes
    if pd.isna(minutes) or minutes == 0:
        return True
    
    return False


def transform_player_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Transform player DataFrame from API format to database format.
    """
    if df.empty:
        return df
    
    # Rename columns: camelCase -> snake_case
    df = df.rename(columns={col: camel_to_snake(col) for col in df.columns})
    
    # Parse minutes
    if 'minutes' in df.columns:
        df['minutes'] = df['minutes'].apply(parse_minutes)
    
    # Add DNP flag
    df['did_not_play'] = df.apply(determine_dnp, axis=1)
    
    # Add timestamp
    df['created_at'] = datetime.now()
    
    return df


def transform_team_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Transform team DataFrame from API format to database format.
    """
    if df.empty:
        return df
    
    # Rename columns: camelCase -> snake_case
    df = df.rename(columns={col: camel_to_snake(col) for col in df.columns})
    
    # Parse minutes
    if 'minutes' in df.columns:
        df['minutes'] = df['minutes'].apply(parse_minutes)
    
    # Add timestamp
    df['created_at'] = datetime.now()
    
    return df


def rate_limit(game_num: int):
    """
    Apply rate limiting between API calls.
    Long pause every LONG_PAUSE_EVERY games.
    """
    if game_num > 0 and game_num % LONG_PAUSE_EVERY == 0:
        pause = round(random.uniform(LONG_PAUSE_MIN, LONG_PAUSE_MAX), 1)
        print(f"\n  ⏸️  Long pause: {pause}s (every {LONG_PAUSE_EVERY} games)\n")
        time.sleep(pause)
    else:
        delay = round(random.uniform(SHORT_DELAY_MIN, SHORT_DELAY_MAX), 2)
        time.sleep(delay)


print("Helper functions loaded ✓")

# Test camel_to_snake
test_cases = ['offensiveRating', 'PIE', 'assistToTurnover', 'gameId', 'estimatedOffensiveRating']
print("\nColumn name transformation test:")
for tc in test_cases:
    print(f"  {tc} -> {camel_to_snake(tc)}")
# Out:
# Helper functions loaded ✓
#
# Column name transformation test:
#   offensiveRating -> offensive_rating
#   PIE -> pie
#   assistToTurnover -> assist_to_turnover
#   gameId -> game_id
#   estimatedOffensiveRating -> estimated_offensive_rating

# %%
# =============================================================================
# Get Game IDs to Scrape
# =============================================================================

def get_all_game_ids(engine) -> list:
    """
    Get all distinct game IDs from team_game_stats.
    """
    query = """
        SELECT DISTINCT game_id 
        FROM team_game_stats 
        ORDER BY game_id
    """
    df = pd.read_sql(query, engine)
    return df['game_id'].tolist()


def get_scraped_game_ids(engine) -> set:
    """Get game IDs that have already been scraped."""
    inspector = inspect(engine)
    
    if 'advanced_player_game_stats' in inspector.get_table_names():
        query = "SELECT DISTINCT game_id FROM advanced_player_game_stats"
        df = pd.read_sql(query, engine)
        return set(df['game_id'].tolist())
    
    return set()


# Get games
print("Fetching game IDs...")
all_game_ids = get_all_game_ids(engine)
print(f"  Total games in database: {len(all_game_ids)}")

print("\nChecking progress...")
scraped_game_ids = get_scraped_game_ids(engine)
print(f"  Already scraped: {len(scraped_game_ids)}")

# Filter to remaining games
games_to_scrape = [g for g in all_game_ids if g not in scraped_game_ids]
print(f"  Remaining to scrape: {len(games_to_scrape)}")

# Estimate time
avg_time_per_game = (SHORT_DELAY_MIN + SHORT_DELAY_MAX) / 2 + 0.5  # API call time
long_pauses = len(games_to_scrape) // LONG_PAUSE_EVERY
estimated_hours = (len(games_to_scrape) * avg_time_per_game + long_pauses * (LONG_PAUSE_MIN + LONG_PAUSE_MAX) / 2) / 3600
print(f"\n⏱️  Estimated time: {estimated_hours:.1f} hours")
# Out:
# Fetching game IDs...
#   Total games in database: 19118
#
# Checking progress...
#   Already scraped: 8450
#   Remaining to scrape: 10668
#
# ⏱️  Estimated time: 9.0 hours

# %%
# =============================================================================
# Single Game Scraper (for testing)
# =============================================================================

def scrape_single_game(game_id: str) -> tuple:
    """
    Scrape advanced stats for a single game.
    
    Returns:
        (player_df, team_df) - Both transformed and ready for DB insertion
    """
    box_adv = boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=game_id)
    dfs = box_adv.get_data_frames()
    
    # dfs[0] = players, dfs[1] = teams
    player_df = transform_player_df(dfs[0].copy())
    team_df = transform_team_df(dfs[1].copy())
    
    return player_df, team_df


# Test with first game
if games_to_scrape:
    test_game_id = games_to_scrape[0]
    print(f"Testing with game: {test_game_id}")
    
    try:
        player_df, team_df = scrape_single_game(test_game_id)
        print(f"\nPlayer DataFrame:")
        print(f"  Shape: {player_df.shape}")
        print(f"  Columns: {list(player_df.columns)}")
        print(f"  DNP players: {player_df['did_not_play'].sum()}")
        
        print(f"\nTeam DataFrame:")
        print(f"  Shape: {team_df.shape}")
        print(f"  Columns: {list(team_df.columns)}")
        
        print("\n✓ Test successful")
    except Exception as e:
        print(f"\n❌ Test failed: {e}")
else:
    print("No games to scrape - all done!")
# Out:
# Testing with game: 0021600032
#
# Player DataFrame:
#   Shape: (26, 39)
#   Columns: ['game_id', 'team_id', 'team_city', 'team_name', 'team_tricode', 'team_slug', 'person_id', 'first_name', 'family_name', 'name_i', 'player_slug', 'position', 'comment', 'jersey_num', 'minutes', 'estimated_offensive_rating', 'offensive_rating', 'estimated_defensive_rating', 'defensive_rating', 'estimated_net_rating', 'net_rating', 'assist_percentage', 'assist_to_turnover', 'assist_ratio', 'offensive_rebound_percentage', 'defensive_rebound_percentage', 'rebound_percentage', 'turnover_ratio', 'effective_field_goal_percentage', 'true_shooting_percentage', 'usage_percentage', 'estimated_usage_percentage', 'estimated_pace', 'pace', 'pace_per40', 'possessions', 'pie', 'did_not_play', 'created_at']
#   DNP players: 2
#
# Team DataFrame:
#   Shape: (2, 31)
#   Columns: ['game_id', 'team_id', 'team_city', 'team_name', 'team_tricode', 'team_slug', 'minutes', 'estimated_offensive_rating', 'offensive_rating', 'estimated_defensive_rating', 'defensive_rating', 'estimated_net_rating', 'net_rating', 'assist_percentage', 'assist_to_turnover', 'assist_ratio', 'offensive_rebound_percentage', 'defensive_rebound_percentage', 'rebound_percentage', 'estimated_team_turnover_percentage', 'turnover_ratio', 'effective_field_goal_percentage', 'true_shooting_percentage', 'usage_percentage', 'estimated_usage_percentage', 'estimated_pace', 'pace', 'pace_per40', 'possessions', 'pie', 'created_at']
#
# ✓ Test successful

# %%
# =============================================================================
# FRESH RESTART - Run this on ALL machines
# =============================================================================

# Re-fetch what's actually remaining RIGHT NOW
print("Fetching current state from database...")
all_game_ids = get_all_game_ids(engine)
scraped_game_ids = get_scraped_game_ids(engine)

# WORKER CONFIGURATION
WORKER_ID = 1        # <--- CHANGE THIS: 1, 2, or 3 for each machine
TOTAL_WORKERS = 3

# Filter games based on Modulo arithmetic
# This guarantees no overlap, regardless of start time or list order
my_games = []
for game_id in all_game_ids:
    # Skip if already scraped
    if game_id in scraped_game_ids:
        continue

    # Check if this game belongs to this worker
    # We convert string "0021800978" to int 21800978
    if int(game_id) % TOTAL_WORKERS == (WORKER_ID - 1):
        my_games.append(game_id)

print(f"Total games in DB: {len(all_game_ids)}")
print(f"Already scraped: {len(scraped_game_ids)}")
print(f"\nWorker {WORKER_ID}/{TOTAL_WORKERS}")
print(f"Allocated games: {len(my_games)}")

if my_games:
    print(f"Sample range: {my_games[0]} ... {my_games[-1]}")
# Out:
# Fetching current state from database...
# Total games in DB: 19118
# Already scraped: 8450
#
# Worker 1/3
# Allocated games: 3556
# Sample range: 0021600033 ... 0022401228

# %%
# =============================================================================
# Main Scraping Loop
# =============================================================================

def check_game_exists(game_id, engine):
    """Checks if a game exists in the DB immediately before scraping."""
    try:
        query = text("SELECT 1 FROM advanced_player_game_stats WHERE
game_id = :gid LIMIT 1")
        with engine.connect() as conn:
            result = conn.execute(query, {"gid": game_id}).fetchone()
            return result is not None
    except Exception:
        return False

def save_batch(player_batch: pd.DataFrame, team_batch: pd.DataFrame,
               progress_batch: list, engine):
    """
    Save a batch of data to the database.
    """
    # Save player stats
    if not player_batch.empty:
        player_batch.to_sql(
            'advanced_player_game_stats',
            engine,
            if_exists='append',
            index=False
        )

    # Save team stats
    if not team_batch.empty:
        team_batch.to_sql(
            'advanced_team_game_stats',
            engine,
            if_exists='append',
            index=False
        )

    # Save progress records
    if progress_batch:
        progress_df = pd.DataFrame(progress_batch)
        progress_df.to_sql(
            'scrape_advanced_stats_progress',
            engine,
            if_exists='append',
            index=False
        )


def run_scraper(games: list, engine, start_index: int = 0):
    """
    Main scraping loop with batch commits and error handling.
    """
    total_games = len(games)

    # Batch accumulators
    player_batch = pd.DataFrame()
    team_batch = pd.DataFrame()
    progress_batch = []

    # Stats
    games_processed = 0
    games_failed = 0
    games_skipped = 0
    start_time = datetime.now()

    print(f"\n{'='*60}")
    print(f"Starting scraper at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"Games to process: {total_games}")
    print(f"Batch size: {BATCH_SIZE}")
    print(f"{'='*60}\n")

    for i, game_id in enumerate(games[start_index:], start=start_index + 1):

        # --- NEW: Check existence before processing to avoid
UniqueViolation ---
        if check_game_exists(game_id, engine):
            print(f"[{i}/{total_games}] Game {game_id} already exists.
Skipping.")
            games_skipped += 1
            continue
        # -----------------------------------------------------------------------

        retries = 0
        success = False

        while retries < MAX_RETRIES and not success:
            try:
                print(f"[{i}/{total_games}] Scraping game: {game_id}", end="")

                # Fetch data
                player_df, team_df = scrape_single_game(game_id)

                # Accumulate
                player_batch = pd.concat([player_batch, player_df],
ignore_index=True)
                team_batch = pd.concat([team_batch, team_df], ignore_index=True)
                progress_batch.append({
                    'game_id': game_id,
                    'scraped_at': datetime.now(),
                    'player_rows_inserted': len(player_df),
                    'team_rows_inserted': len(team_df),
                    'status': 'success'
                })

                games_processed += 1
                print(f" ✓ ({len(player_df)} players, {len(team_df)} teams)")
                success = True

                # Save batch if full
                if games_processed % BATCH_SIZE == 0:
                    print(f"\n  💾 Saving batch ({games_processed}
games processed)...")
                    try:
                        save_batch(player_batch, team_batch,
progress_batch, engine)
                        print(f"  ✓ Batch saved: {len(player_batch)}
player rows, {len(team_batch)} team rows")
                        # Clear only on success
                        player_batch = pd.DataFrame()
                        team_batch = pd.DataFrame()
                        progress_batch = []
                    except Exception as e:
                        print(f"  ❌ Batch save failed: {e}")
                        print(f"  ⚠️  CRITICAL: Batch failed. Data for
last {BATCH_SIZE} games NOT saved.")
                        # NOTE: We do NOT clear the batch here in a
real production app usually,
                        # but given your script's logic, we have to
let it clear or it will retry forever.
                        # The 'check_game_exists' at the top should
prevent 99% of these errors now.
                        player_batch = pd.DataFrame()
                        team_batch = pd.DataFrame()
                        progress_batch = []
                        engine.dispose()

                    print()

                # Rate limiting
                rate_limit(games_processed)

            except (ReadTimeout, ConnectionError, json.JSONDecodeError) as e:
                retries += 1
                print(f" ⚠️  Error (attempt {retries}/{MAX_RETRIES}):
{type(e).__name__}")

                if retries < MAX_RETRIES:
                    print(f"      Waiting {ERROR_RETRY_DELAY}s before retry...")
                    time.sleep(ERROR_RETRY_DELAY)
                else:
                    print(f"      ❌ Skipping game after {MAX_RETRIES} failures")
                    progress_batch.append({
                        'game_id': game_id,
                        'scraped_at': datetime.now(),
                        'player_rows_inserted': 0,
                        'team_rows_inserted': 0,
                        'status': 'failed'
                    })
                    games_failed += 1

            except Exception as e:
                print(f" ❌ Unexpected error: {e}")
                retries += 1
                if retries >= MAX_RETRIES:
                    progress_batch.append({
                        'game_id': game_id,
                        'scraped_at': datetime.now(),
                        'player_rows_inserted': 0,
                        'team_rows_inserted': 0,
                        'status': 'failed'
                    })
                    games_failed += 1
                else:
                    time.sleep(ERROR_RETRY_DELAY)

    # Save any remaining data
    if player_batch.shape[0] > 0 or team_batch.shape[0] > 0 or progress_batch:
        print(f"\n  💾 Saving final batch...")
        save_batch(player_batch, team_batch, progress_batch, engine)
        print(f"  ✓ Final batch saved")

    # Summary
    end_time = datetime.now()
    duration = end_time - start_time

    print(f"\n{'='*60}")
    print(f"SCRAPING COMPLETE")
    print(f"{'='*60}")
    print(f"Duration: {duration}")
    print(f"Games processed: {games_processed}")
    print(f"Games skipped (already in DB): {games_skipped}")
    print(f"Games failed: {games_failed}")
    print(f"{'='*60}")

    return games_processed, games_failed
# Out:
#   Cell In[15], line 8
#     query = text("SELECT 1 FROM advanced_player_game_stats WHERE
#                  ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
# =============================================================================
# RUN THE SCRAPER
# =============================================================================

# ⚠️  This will take several hours for ~12,000 games
# The scraper is resumable - if it crashes, just re-run this cell

if len(games_to_scrape) == 0:
    print("✅ All games already scraped! Nothing to do.")
else:
    # Uncomment to run:
    processed, failed = run_scraper(my_games, engine)
    
    print(f"Ready to scrape {len(games_to_scrape)} games.")
    print(f"Uncomment the line above and re-run this cell to start.")
# Out:
# ============================================================
# Starting scraper at 2026-01-09 10:19:56
# Games to process: 3656
# Batch size: 50
# ============================================================
#
# [1/3656] Scraping game: 0021501012 ✓ (26 players, 2 teams)
# [2/3656] Scraping game: 0021501013 ✓ (26 players, 2 teams)
# [3/3656] Scraping game: 0021501014 ✓ (25 players, 2 teams)
# [4/3656] Scraping game: 0021501015 ✓ (25 players, 2 teams)
# [5/3656] Scraping game: 0021501016 ✓ (26 players, 2 teams)
# [6/3656] Scraping game: 0021501017 ✓ (26 players, 2 teams)
# [7/3656] Scraping game: 0021501018 ✓ (26 players, 2 teams)
# [8/3656] Scraping game: 0021501019 ✓ (24 players, 2 teams)
# [9/3656] Scraping game: 0021501020 ✓ (26 players, 2 teams)
# [10/3656] Scraping game: 0021501021 ✓ (26 players, 2 teams)
# [11/3656] Scraping game: 0021501022 ✓ (26 players, 2 teams)
# [12/3656] Scraping game: 0021501023 ✓ (26 players, 2 teams)
# [13/3656] Scraping game: 0021501024 ✓ (25 players, 2 teams)
# [14/3656] Scraping game: 0021501025 ✓ (26 players, 2 teams)
# [15/3656] Scraping game: 0021501026 ✓ (25 players, 2 teams)
# [16/3656] Scraping game: 0021501027 ✓ (25 players, 2 teams)
# [17/3656] Scraping game: 0021501028 ✓ (26 players, 2 teams)
# [18/3656] Scraping game: 0021501029 ✓ (25 players, 2 teams)
# [19/3656] Scraping game: 0021501030 ✓ (26 players, 2 teams)
# [20/3656] Scraping game: 0021501031 ✓ (26 players, 2 teams)
# [21/3656] Scraping game: 0021501032 ✓ (26 players, 2 teams)
# [22/3656] Scraping game: 0021501033 ✓ (25 players, 2 teams)
# [23/3656] Scraping game: 0021501034 ✓ (25 players, 2 teams)
# [24/3656] Scraping game: 0021501035 ✓ (26 players, 2 teams)
# [25/3656] Scraping game: 0021501036 ✓ (25 players, 2 teams)
# [26/3656] Scraping game: 0021501037 ✓ (26 players, 2 teams)
# [27/3656] Scraping game: 0021501038 ✓ (26 players, 2 teams)
# [28/3656] Scraping game: 0021501039 ✓ (26 players, 2 teams)
# [29/3656] Scraping game: 0021501040 ✓ (25 players, 2 teams)
# [30/3656] Scraping game: 0021501041 ✓ (25 players, 2 teams)
# [31/3656] Scraping game: 0021501042 ✓ (26 players, 2 teams)
# [32/3656] Scraping game: 0021501043 ✓ (26 players, 2 teams)
# [33/3656] Scraping game: 0021501044 ✓ (26 players, 2 teams)
# [34/3656] Scraping game: 0021501045 ✓ (26 players, 2 teams)
# [35/3656] Scraping game: 0021501046 ✓ (26 players, 2 teams)
# [36/3656] Scraping game: 0021501047 ✓ (26 players, 2 teams)
# [37/3656] Scraping game: 0021501048 ✓ (25 players, 2 teams)
# [38/3656] Scraping game: 0021501049 ✓ (26 players, 2 teams)
# [39/3656] Scraping game: 0021501050 ✓ (24 players, 2 teams)
# [40/3656] Scraping game: 0021501051 ✓ (25 players, 2 teams)
# [41/3656] Scraping game: 0021501052 ✓ (26 players, 2 teams)
# [42/3656] Scraping game: 0021501053 ✓ (24 players, 2 teams)
# [43/3656] Scraping game: 0021501054 ✓ (26 players, 2 teams)
# [44/3656] Scraping game: 0021501055 ✓ (26 players, 2 teams)
# [45/3656] Scraping game: 0021501056 ✓ (25 players, 2 teams)
# [46/3656] Scraping game: 0021501057 ✓ (25 players, 2 teams)
# [47/3656] Scraping game: 0021501058 ✓ (26 players, 2 teams)
# [48/3656] Scraping game: 0021501059 ✓ (26 players, 2 teams)
# [49/3656] Scraping game: 0021501060 ✓ (25 players, 2 teams)
# [50/3656] Scraping game: 0021501061 ✓ (25 players, 2 teams)
#
#   💾 Saving batch (50 games processed)...
#   ✓ Batch saved: 1277 player rows, 100 team rows
#
# [51/3656] Scraping game: 0021501062 ✓ (25 players, 2 teams)
# [52/3656] Scraping game: 0021501063 ✓ (25 players, 2 teams)
# [53/3656] Scraping game: 0021501064 ✓ (26 players, 2 teams)
# [54/3656] Scraping game: 0021501065 ✓ (25 players, 2 teams)
# [55/3656] Scraping game: 0021501066 ✓ (25 players, 2 teams)
# [56/3656] Scraping game: 0021501067 ✓ (26 players, 2 teams)
# [57/3656] Scraping game: 0021501068 ✓ (26 players, 2 teams)
# [58/3656] Scraping game: 0021501069 ✓ (26 players, 2 teams)
# [59/3656] Scraping game: 0021501070 ✓ (25 players, 2 teams)
# [60/3656] Scraping game: 0021501071 ✓ (25 players, 2 teams)
# [61/3656] Scraping game: 0021501072 ✓ (25 players, 2 teams)
# [62/3656] Scraping game: 0021501073 ✓ (25 players, 2 teams)
# [63/3656] Scraping game: 0021501074 ✓ (26 players, 2 teams)
# [64/3656] Scraping game: 0021501075 ✓ (25 players, 2 teams)
# [65/3656] Scraping game: 0021501076 ✓ (25 players, 2 teams)
# [66/3656] Scraping game: 0021501077 ✓ (26 players, 2 teams)
# [67/3656] Scraping game: 0021501078 ✓ (26 players, 2 teams)
# [68/3656] Scraping game: 0021501079 ✓ (25 players, 2 teams)
# [69/3656] Scraping game: 0021501080 ✓ (25 players, 2 teams)
# [70/3656] Scraping game: 0021501081 ✓ (26 players, 2 teams)
# [71/3656] Scraping game: 0021501082 ✓ (26 players, 2 teams)
# [72/3656] Scraping game: 0021501083 ✓ (26 players, 2 teams)
# [73/3656] Scraping game: 0021501084 ✓ (26 players, 2 teams)
# [74/3656] Scraping game: 0021501085 ✓ (25 players, 2 teams)
# [75/3656] Scraping game: 0021501086 ✓ (25 players, 2 teams)
# [76/3656] Scraping game: 0021501087 ✓ (24 players, 2 teams)
# [77/3656] Scraping game: 0021501088 ✓ (26 players, 2 teams)
# [78/3656] Scraping game: 0021501089 ✓ (25 players, 2 teams)
# [79/3656] Scraping game: 0021501090 ✓ (25 players, 2 teams)
# [80/3656] Scraping game: 0021501091 ✓ (26 players, 2 teams)
# [81/3656] Scraping game: 0021501092 ✓ (26 players, 2 teams)
# [82/3656] Scraping game: 0021501093 ✓ (26 players, 2 teams)
# [83/3656] Scraping game: 0021501094 ✓ (25 players, 2 teams)
# [84/3656] Scraping game: 0021501095 ✓ (26 players, 2 teams)
# [85/3656] Scraping game: 0021501096 ✓ (26 players, 2 teams)
# [86/3656] Scraping game: 0021501097 ✓ (25 players, 2 teams)
# [87/3656] Scraping game: 0021501098 ✓ (25 players, 2 teams)
# [88/3656] Scraping game: 0021501099 ✓ (25 players, 2 teams)
# [89/3656] Scraping game: 0021501100 ✓ (26 players, 2 teams)
# [90/3656] Scraping game: 0021501101 ✓ (24 players, 2 teams)
# [91/3656] Scraping game: 0021501102 ✓ (25 players, 2 teams)
# [92/3656] Scraping game: 0021501103 ✓ (25 players, 2 teams)
# [93/3656] Scraping game: 0021501104 ✓ (25 players, 2 teams)
# [94/3656] Scraping game: 0021501105 ✓ (26 players, 2 teams)
# [95/3656] Scraping game: 0021501106 ✓ (26 players, 2 teams)
# [96/3656] Scraping game: 0021501107 ✓ (26 players, 2 teams)
# [97/3656] Scraping game: 0021501108 ✓ (26 players, 2 teams)
# [98/3656] Scraping game: 0021501109 ✓ (26 players, 2 teams)
# [99/3656] Scraping game: 0021501110 ✓ (26 players, 2 teams)
# [100/3656] Scraping game: 0021501111 ✓ (26 players, 2 teams)
#
#   💾 Saving batch (100 games processed)...
#   ✓ Batch saved: 1273 player rows, 100 team rows
#
#
#   ⏸️  Long pause: 75.4s (every 100 games)
#
# [101/3656] Scraping game: 0021501112 ✓ (25 players, 2 teams)
# [102/3656] Scraping game: 0021501113 ✓ (25 players, 2 teams)
# [103/3656] Scraping game: 0021501114 ✓ (25 players, 2 teams)
# [104/3656] Scraping game: 0021501115 ✓ (24 players, 2 teams)
# [105/3656] Scraping game: 0021501116 ✓ (25 players, 2 teams)
# [106/3656] Scraping game: 0021501117 ✓ (25 players, 2 teams)
# [107/3656] Scraping game: 0021501118 ✓ (26 players, 2 teams)
# [108/3656] Scraping game: 0021501119 ✓ (24 players, 2 teams)
# [109/3656] Scraping game: 0021501120 ✓ (26 players, 2 teams)
# [110/3656] Scraping game: 0021501121 ✓ (25 players, 2 teams)
# [111/3656] Scraping game: 0021501122 ✓ (26 players, 2 teams)
# [112/3656] Scraping game: 0021501123 ✓ (26 players, 2 teams)
# [113/3656] Scraping game: 0021501124 ✓ (26 players, 2 teams)
# [114/3656] Scraping game: 0021501125 ✓ (25 players, 2 teams)
# [115/3656] Scraping game: 0021501126 ✓ (26 players, 2 teams)
# [116/3656] Scraping game: 0021501127 ✓ (26 players, 2 teams)
# [117/3656] Scraping game: 0021501128 ✓ (26 players, 2 teams)
# [118/3656] Scraping game: 0021501129 ✓ (26 players, 2 teams)
# [119/3656] Scraping game: 0021501130 ✓ (25 players, 2 teams)
# [120/3656] Scraping game: 0021501131 ✓ (25 players, 2 teams)
# [121/3656] Scraping game: 0021501132 ✓ (26 players, 2 teams)
# [122/3656] Scraping game: 0021501133 ✓ (25 players, 2 teams)
# [123/3656] Scraping game: 0021501134 ✓ (24 players, 2 teams)
# [124/3656] Scraping game: 0021501135 ✓ (25 players, 2 teams)
# [125/3656] Scraping game: 0021501136 ✓ (25 players, 2 teams)
# [126/3656] Scraping game: 0021501137 ✓ (25 players, 2 teams)
# [127/3656] Scraping game: 0021501138 ✓ (26 players, 2 teams)
# [128/3656] Scraping game: 0021501139 ✓ (26 players, 2 teams)
# [129/3656] Scraping game: 0021501140 ✓ (25 players, 2 teams)
# [130/3656] Scraping game: 0021501141 ✓ (26 players, 2 teams)
# [131/3656] Scraping game: 0021501142 ✓ (25 players, 2 teams)
# [132/3656] Scraping game: 0021501143 ✓ (26 players, 2 teams)
# [133/3656] Scraping game: 0021501144 ✓ (26 players, 2 teams)
# [134/3656] Scraping game: 0021501145 ✓ (26 players, 2 teams)
# [135/3656] Scraping game: 0021501146 ✓ (25 players, 2 teams)
# [136/3656] Scraping game: 0021501147 ✓ (26 players, 2 teams)
# [137/3656] Scraping game: 0021501148 ✓ (26 players, 2 teams)
# [138/3656] Scraping game: 0021501149 ✓ (24 players, 2 teams)
# [139/3656] Scraping game: 0021501150 ✓ (25 players, 2 teams)
# [140/3656] Scraping game: 0021501151 ✓ (25 players, 2 teams)
# [141/3656] Scraping game: 0021501152 ✓ (26 players, 2 teams)
# [142/3656] Scraping game: 0021501153 ✓ (25 players, 2 teams)
# [143/3656] Scraping game: 0021501154 ✓ (26 players, 2 teams)
# [144/3656] Scraping game: 0021501155 ✓ (25 players, 2 teams)
# [145/3656] Scraping game: 0021501156 ✓ (26 players, 2 teams)
# [146/3656] Scraping game: 0021501157 ✓ (24 players, 2 teams)
# [147/3656] Scraping game: 0021501158 ✓ (26 players, 2 teams)
# [148/3656] Scraping game: 0021501159 ✓ (25 players, 2 teams)
# [149/3656] Scraping game: 0021501160 ✓ (26 players, 2 teams)
# [150/3656] Scraping game: 0021501161 ✓ (26 players, 2 teams)
#
#   💾 Saving batch (150 games processed)...
#   ✓ Batch saved: 1269 player rows, 100 team rows
#
# [151/3656] Scraping game: 0021501162 ✓ (26 players, 2 teams)
# [152/3656] Scraping game: 0021501163 ✓ (25 players, 2 teams)
# [153/3656] Scraping game: 0021501164 ✓ (26 players, 2 teams)
# [154/3656] Scraping game: 0021501165 ✓ (26 players, 2 teams)
# [155/3656] Scraping game: 0021501166 ✓ (26 players, 2 teams)
# [156/3656] Scraping game: 0021501167 ✓ (24 players, 2 teams)
# [157/3656] Scraping game: 0021501168 ✓ (26 players, 2 teams)
# [158/3656] Scraping game: 0021501169 ✓ (25 players, 2 teams)
# [159/3656] Scraping game: 0021501170 ✓ (26 players, 2 teams)
# [160/3656] Scraping game: 0021501171 ✓ (26 players, 2 teams)
# [161/3656] Scraping game: 0021501172 ✓ (26 players, 2 teams)
# [162/3656] Scraping game: 0021501173 ✓ (25 players, 2 teams)
# [163/3656] Scraping game: 0021501174 ✓ (25 players, 2 teams)
# [164/3656] Scraping game: 0021501175 ✓ (25 players, 2 teams)
# [165/3656] Scraping game: 0021501176 ✓ (25 players, 2 teams)
# [166/3656] Scraping game: 0021501177 ✓ (26 players, 2 teams)
# [167/3656] Scraping game: 0021501178 ✓ (25 players, 2 teams)
# [168/3656] Scraping game: 0021501179 ✓ (25 players, 2 teams)
# [169/3656] Scraping game: 0021501180 ✓ (25 players, 2 teams)
# [170/3656] Scraping game: 0021501181 ✓ (25 players, 2 teams)
# [171/3656] Scraping game: 0021501182 ✓ (26 players, 2 teams)
# [172/3656] Scraping game: 0021501183 ✓ (26 players, 2 teams)
# [173/3656] Scraping game: 0021501184 ✓ (26 players, 2 teams)
# [174/3656] Scraping game: 0021501185 ✓ (26 players, 2 teams)
# [175/3656] Scraping game: 0021501186 ✓ (25 players, 2 teams)
# [176/3656] Scraping game: 0021501187 ✓ (26 players, 2 teams)
# [177/3656] Scraping game: 0021501188 ✓ (25 players, 2 teams)
# [178/3656] Scraping game: 0021501189 ✓ (25 players, 2 teams)
# [179/3656] Scraping game: 0021501190 ✓ (26 players, 2 teams)
# [180/3656] Scraping game: 0021501191 ✓ (26 players, 2 teams)
# [181/3656] Scraping game: 0021501192 ✓ (25 players, 2 teams)
# [182/3656] Scraping game: 0021501193 ✓ (26 players, 2 teams)
# [183/3656] Scraping game: 0021501194 ✓ (26 players, 2 teams)
# [184/3656] Scraping game: 0021501195 ✓ (26 players, 2 teams)
# [185/3656] Scraping game: 0021501196 ✓ (26 players, 2 teams)
# [186/3656] Scraping game: 0021501197 ✓ (25 players, 2 teams)
# [187/3656] Scraping game: 0021501198 ✓ (26 players, 2 teams)
# [188/3656] Scraping game: 0021501199 ✓ (25 players, 2 teams)
# [189/3656] Scraping game: 0021501200 ✓ (25 players, 2 teams)
# [190/3656] Scraping game: 0021501201 ✓ (26 players, 2 teams)
# [191/3656] Scraping game: 0021501202 ✓ (25 players, 2 teams)
# [192/3656] Scraping game: 0021501203 ✓ (25 players, 2 teams)
# [193/3656] Scraping game: 0021501204 ✓ (25 players, 2 teams)
# [194/3656] Scraping game: 0021501205 ✓ (26 players, 2 teams)
# [195/3656] Scraping game: 0021501206 ✓ (24 players, 2 teams)
# [196/3656] Scraping game: 0021501207 ✓ (25 players, 2 teams)
# [197/3656] Scraping game: 0021501208 ✓ (26 players, 2 teams)
# [198/3656] Scraping game: 0021501209 ✓ (26 players, 2 teams)
# [199/3656] Scraping game: 0021501210 ✓ (26 players, 2 teams)
# [200/3656] Scraping game: 0021501211 ✓ (25 players, 2 teams)
#
#   💾 Saving batch (200 games processed)...
#   ✓ Batch saved: 1274 player rows, 100 team rows
#
#
#   ⏸️  Long pause: 84.7s (every 100 games)
#
# [201/3656] Scraping game: 0021501212 ✓ (25 players, 2 teams)
# [202/3656] Scraping game: 0021501213 ✓ (25 players, 2 teams)
# [203/3656] Scraping game: 0021501214 ✓ (26 players, 2 teams)
# [204/3656] Scraping game: 0021501215 ✓ (26 players, 2 teams)
# [205/3656] Scraping game: 0021501216 ✓ (25 players, 2 teams)
# [206/3656] Scraping game: 0021501217 ✓ (26 players, 2 teams)
# [207/3656] Scraping game: 0021501218 ✓ (25 players, 2 teams)
# [208/3656] Scraping game: 0021501219 ✓ (26 players, 2 teams)
# [209/3656] Scraping game: 0021501220 ✓ (26 players, 2 teams)
# [210/3656] Scraping game: 0021501221 ✓ (24 players, 2 teams)
# [211/3656] Scraping game: 0021501222 ✓ (26 players, 2 teams)
# [212/3656] Scraping game: 0021501223 ✓ (26 players, 2 teams)
# [213/3656] Scraping game: 0021501224 ✓ (26 players, 2 teams)
# [214/3656] Scraping game: 0021501225 ✓ (25 players, 2 teams)
# [215/3656] Scraping game: 0021501226 ✓ (25 players, 2 teams)
# [216/3656] Scraping game: 0021501227 ✓ (26 players, 2 teams)
# [217/3656] Scraping game: 0021501228 ✓ (26 players, 2 teams)
# [218/3656] Scraping game: 0021501229 ✓ (25 players, 2 teams)
# [219/3656] Scraping game: 0021501230 ✓ (26 players, 2 teams)
# [220/3656] Scraping game: 0021600001 ✓ (26 players, 2 teams)
# [221/3656] Scraping game: 0021600002 ✓ (26 players, 2 teams)
# [222/3656] Scraping game: 0021600003 ✓ (26 players, 2 teams)
# [223/3656] Scraping game: 0021600004 ✓ (26 players, 2 teams)
# [224/3656] Scraping game: 0021600005 ✓ (26 players, 2 teams)
# [225/3656] Scraping game: 0021600006 ✓ (26 players, 2 teams)
# [226/3656] Scraping game: 0021600007 ✓ (26 players, 2 teams)
# [227/3656] Scraping game: 0021600008 ✓ (26 players, 2 teams)
# [228/3656] Scraping game: 0021600009 ✓ (26 players, 2 teams)
# [229/3656] Scraping game: 0021600010 ✓ (26 players, 2 teams)
# [230/3656] Scraping game: 0021600011 ✓ (25 players, 2 teams)
# [231/3656] Scraping game: 0021600012 ✓ (26 players, 2 teams)
# [232/3656] Scraping game: 0021600013 ✓ (26 players, 2 teams)
# [233/3656] Scraping game: 0021600014 ✓ (26 players, 2 teams)
# [234/3656] Scraping game: 0021600015 ✓ (26 players, 2 teams)
# [235/3656] Scraping game: 0021600016 ✓ (26 players, 2 teams)
# [236/3656] Scraping game: 0021600017 ✓ (26 players, 2 teams)
# [237/3656] Scraping game: 0021600018 ✓ (26 players, 2 teams)
# [238/3656] Scraping game: 0021600019 ✓ (26 players, 2 teams)
# [239/3656] Scraping game: 0021600020 ✓ (26 players, 2 teams)
# [240/3656] Scraping game: 0021600021 ✓ (26 players, 2 teams)
# [241/3656] Scraping game: 0021600022 ✓ (26 players, 2 teams)
# [242/3656] Scraping game: 0021600023 ✓ (26 players, 2 teams)
# [243/3656] Scraping game: 0021600024 ✓ (26 players, 2 teams)
# [244/3656] Scraping game: 0021600025 ✓ (26 players, 2 teams)
# [245/3656] Scraping game: 0021600026 ✓ (25 players, 2 teams)
# [246/3656] Scraping game: 0021600027 ✓ (26 players, 2 teams)
# [247/3656] Scraping game: 0021600028 ✓ (26 players, 2 teams)
# [248/3656] Scraping game: 0021600029 ✓ (26 players, 2 teams)
# [249/3656] Scraping game: 0021600030 ✓ (26 players, 2 teams)
# [250/3656] Scraping game: 0021600031 ✓ (26 players, 2 teams)
#
#   💾 Saving batch (250 games processed)...
#   ✓ Batch saved: 1289 player rows, 100 team rows
#
# [251/3656] Scraping game: 0021600032 ✓ (26 players, 2 teams)
# [252/3656] Scraping game: 0021600033 ✓ (26 players, 2 teams)
# [253/3656] Scraping game: 0021600034 ✓ (26 players, 2 teams)
# [254/3656] Scraping game: 0021600035 ✓ (26 players, 2 teams)
# [255/3656] Scraping game: 0021600036 ✓ (26 players, 2 teams)
# [256/3656] Scraping game: 0021600037 ✓ (26 players, 2 teams)
# [257/3656] Scraping game: 0021600038 ✓ (26 players, 2 teams)
# [258/3656] Scraping game: 0021600039 ✓ (26 players, 2 teams)
# [259/3656] Scraping game: 0021600040 ✓ (26 players, 2 teams)
# [260/3656] Scraping game: 0021600041 ✓ (26 players, 2 teams)
# [261/3656] Scraping game: 0021600042 ✓ (26 players, 2 teams)
# [262/3656] Scraping game: 0021600043 ✓ (26 players, 2 teams)
# [263/3656] Scraping game: 0021600044 ✓ (26 players, 2 teams)
# [264/3656] Scraping game: 0021600045 ✓ (26 players, 2 teams)
# [265/3656] Scraping game: 0021600046 ✓ (25 players, 2 teams)
# [266/3656] Scraping game: 0021600047 ✓ (26 players, 2 teams)
# [267/3656] Scraping game: 0021600048 ✓ (26 players, 2 teams)
# [268/3656] Scraping game: 0021600049 ✓ (26 players, 2 teams)
# [269/3656] Scraping game: 0021600050 ✓ (26 players, 2 teams)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#       9     print("✅ All games already scraped! Nothing to do.")
#      10 else:
#      11     # Uncomment to run:
# ---> 12     processed, failed = run_scraper(my_games, engine)
#      14     print(f"Ready to scrape {len(games_to_scrape)} games.")
#      15     print(f"Uncomment the line above and re-run this cell to start.")
#
# Cell In[7], line 110, in run_scraper(games, engine, start_index)
#     107         print()
#     109     # Rate limiting
# --> 110     rate_limit(games_processed)
#     112 except (ReadTimeout, ConnectionError, json.JSONDecodeError) as e:
#     113     retries += 1
#
# Cell In[3], line 135, in rate_limit(game_num)
#     133 else:
#     134     delay = round(random.uniform(SHORT_DELAY_MIN, SHORT_DELAY_MAX), 2)
# --> 135     time.sleep(delay)
#
# KeyboardInterrupt:

# %%
# =============================================================================
# Verification Queries
# =============================================================================

print("Checking scrape results...\n")

# Row counts
player_count = pd.read_sql("SELECT COUNT(*) as cnt FROM advanced_player_game_stats", engine)['cnt'].iloc[0]
team_count = pd.read_sql("SELECT COUNT(*) as cnt FROM advanced_team_game_stats", engine)['cnt'].iloc[0]
progress_count = pd.read_sql("SELECT COUNT(*) as cnt FROM scrape_advanced_stats_progress WHERE status = 'success'", engine)['cnt'].iloc[0]

print(f"Player stats rows: {player_count:,}")
print(f"Team stats rows: {team_count:,}")
print(f"Games successfully scraped: {progress_count:,}")

# Failed games
failed_games = pd.read_sql("""
    SELECT game_id, scraped_at 
    FROM scrape_advanced_stats_progress 
    WHERE status = 'failed'
    ORDER BY scraped_at DESC
""", engine)

if len(failed_games) > 0:
    print(f"\n⚠️  Failed games: {len(failed_games)}")
    print(failed_games.head(10))
else:
    print(f"\n✅ No failed games")

# DNP distribution
dnp_dist = pd.read_sql("""
    SELECT did_not_play, COUNT(*) as count
    FROM advanced_player_game_stats
    GROUP BY did_not_play
""", engine)
print(f"\nDNP distribution:")
print(dnp_dist)

# %%
# =============================================================================
# Retry Failed Games (Optional)
# =============================================================================

# Get failed games
failed_games = pd.read_sql("""
    SELECT game_id 
    FROM scrape_advanced_stats_progress 
    WHERE status = 'failed'
""", engine)

if len(failed_games) > 0:
    failed_game_ids = failed_games['game_id'].tolist()
    print(f"Found {len(failed_game_ids)} failed games to retry")
    
    # First, delete the failed progress records so they can be re-inserted
    # Uncomment to retry:
    # with engine.connect() as conn:
    #     conn.execute(text("DELETE FROM scrape_advanced_stats_progress WHERE status = 'failed'"))
    #     conn.commit()
    # 
    # processed, failed = run_scraper(failed_game_ids, engine)
else:
    print("No failed games to retry")

# %%
# =============================================================================
# Sample Data Preview
# =============================================================================

print("Sample player advanced stats:")
sample_player = pd.read_sql("""
    SELECT game_id, person_id, first_name, family_name, team_tricode,
           minutes, offensive_rating, defensive_rating, net_rating,
           usage_percentage, true_shooting_percentage, pie, did_not_play
    FROM advanced_player_game_stats
    WHERE did_not_play = FALSE
    LIMIT 10
""", engine)
display(sample_player)

print("\nSample team advanced stats:")
sample_team = pd.read_sql("""
    SELECT game_id, team_id, team_tricode,
           minutes, offensive_rating, defensive_rating, net_rating,
           pace, possessions, pie
    FROM advanced_team_game_stats
    LIMIT 10
""", engine)
display(sample_team)
